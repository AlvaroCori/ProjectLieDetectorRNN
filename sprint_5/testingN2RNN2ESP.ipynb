# %% [markdown]
# ## Antiguo proyecto de Redes Neuronales Recurrentes usando audios .wav, obteniendo su MFCC, aplicandolos a una RNN y validandolo con k fold cross validation

# %% [markdown]
# #### Librerias

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display
import os
import soundfile as sf
import json
import random
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np

from keras import Sequential
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed

import datetime
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
random.seed(0)

# %% [markdown]
# #### Funciones a usar

# %%
#Obtiene el path con el nombre de todos los archivos de un directorio.
def get_files_from_path(directory):
    path_files = []
    dir_list = os.listdir(directory)
    for path in dir_list:
        path_files.append(directory+"\\"+path)
    return path_files


#Extrae los paths que cumplan con un codigo
def extract_paths_for_emotions_keys(emotions_code, files_path, get_code):
    paths = []
    emotions_set = set(emotions_code)
    for code_file in files_path:
        if (get_code(code_file) in emotions_set):
            paths.append(code_file)
    return paths


#Obtiene el codigo en el nombre del archivo para el dataset CREMA-D
def get_code_esp(path):
    return path[114]#path[110] prueba

def scaled_datas(X):
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled

#Esta función abre el archivo .wav y obtiene el mfcc escalado en un vector de 40 elementos.
def features_extractor(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=120)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except:
        print("rrrr-", file_name)


#Esta función permite guardar los MFCC en 'features', el código en 'code' y su dirección en 'path' en un archivo json. 
def save_elements_in_json(examples_saved, name):
    json_files = []
    json_file = {}
    index = 0
    for file in examples_saved:
        json_file = {"id": index, "features":[str(elem) for elem in file[0]] ,"code":file[1], "path":file[2]}
        json_files.append(json_file)
        index += 1
    json_object = json.dumps(json_files)
    with open(f"{name}.json", "w") as outfile:
        outfile.write(json_object)
   

#La función permite cargar datos del MFCC y código desde un archivo json.
def load_elements_from_json(name):
    f = open(f'{name}.json')
    data = json.load(f)
    examples = []
    for element in data:
        examples.append(([float(feature) for feature in (element["features"])], element["code"]))
    return examples


#La función nos permite devolver una lista de MFCC obtenidos de una lista de paths. 
#El MFCC tiene un límite que no le permite cargar archivos menor o igual a 44 kb.
#Con el diccionario obtenemos el total de audios recuperados por emoción.
def get_features(paths,get_code, files_filters = dict()):
    examples = []
    for path in paths:
        code = get_code(path)
        file_stats = os.stat(path)
        feature = features_extractor(path)
        files_filters[code]+= 1
        examples.append((feature,code))
    print(f"Se obtuvo el MFCC de unos {len(paths)} sobre {sum(files_filters[files] for files in files_filters)} audios.")
    return examples


#Selecciona n ejemplos que necesitemos y los mezcla.
def select_elements(examples, code, quantity, new_code):
    random.shuffle(examples)
    elements = []
    counter = 1
    for example in examples:
        if (counter > quantity):
            break
        if code == example[1]:
            elements.append((example[0],new_code))
            counter = counter + 1
    return elements

# %% [markdown]
# Los siguientes bloques obtienen los paths y filtra las emociones que necesitemos en cada dataset (CREMA-D y SAVEE).

# %% [markdown]
# #### Funciones para obtener los datos

# %%
#Obtiene todos los datos de CREMA-D y SAVEE para un  
def get_datas():
    files_path = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\data")
    emotions_code = ["t", "f"]
    datas_files = extract_paths_for_emotions_keys(emotions_code, files_path, get_code_esp)
    examples = []
    files_filters = dict()
    files_filters["t"] = 0
    files_filters["f"] = 0
    examples = get_features(datas_files, get_code_esp, files_filters)
    return examples

#Obtiene los datos de entrada para la red neuronal x: mfcc normalizados, y: labeles categorizados
def get_entries():
    all_examples = get_datas()
    entries = []
    for example in all_examples:
        entries.append((example[0], example[1]))
    datas = select_elements(entries, 't', 800,"without_stress")
    datas += select_elements(entries, 'f', 800, "stress")
    random.shuffle(datas)
    X = []
    y = []
    for data in datas:
        X.append(data[0])
        y.append(data[1])
    labelencoder=preprocessing.LabelEncoder()
    y = to_categorical(labelencoder.fit_transform(y))
    return X, y

#Obtiene los datos divididos de entrenamiento y tests
def obtain_datas_train_and_test(percentage):
    X, y = get_entries()
    
    X_test, X_train, y_test, y_train = train_test_split(X, y, test_size =percentage,random_state=0)
    y = np.array(y)
    X_train = np.array(X_train)
    X_test = np.array(X_test)
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    return X_train, X_test, y_train, y_test

# %%
audio, sample_rate = librosa.load(get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\data")[0], res_type='kaiser_fast')
mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate)
mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)

# %%
X_train, X_test, y_train, y_test = obtain_datas_train_and_test(0.8)
num_labels = y_train.shape[1] + y_test.shape[1]
dim_entrada = (X_train.shape[1],1)
# Out:
# Se obtuvo el MFCC de unos 1600 sobre 1600 audios.

# %%
X_train[0]
# Out:
# array([-2.03619125e+02,  1.32924957e+02,  1.16074324e+01,  4.22039948e+01,
#         1.59348106e+01,  1.00078325e+01,  3.09595966e+00,  9.74628162e+00,
#        -6.43884420e+00,  5.50276041e+00, -3.89752269e+00,  3.09939122e+00,
#         1.09478855e+00,  3.97362924e+00,  1.78057158e+00,  6.92045116e+00,
#         9.58635986e-01,  1.92379892e+00,  1.48452592e+00, -2.62816620e+00,
#        -3.95873570e+00,  1.12830214e-01, -7.04381943e+00, -3.05793919e-02,
#        -4.39929628e+00,  6.19296312e-01, -3.25743532e+00, -2.55520612e-01,
#        -6.84725106e-01, -8.80580246e-01,  2.59195876e+00, -2.84970117e+00,
#        -1.94983974e-01, -3.07813001e+00, -1.43103153e-01, -1.69904196e+00,
#        -7.15058565e-01, -6.39670566e-02, -1.59365737e+00, -6.24961972e-01,
#        -1.28589094e+00, -8.32239866e-01, -1.48938048e+00, -2.05799675e+00,
#        -1.70092893e+00, -1.23569417e+00, -1.14579642e+00, -2.12408257e+00,
#        -7.98299491e-01, -2.29822969e+00, -1.33868229e+00, -1.82362700e+00,
#        -1.52662444e+00, -1.35500062e+00, -7.45801091e-01, -2.06426457e-01,
#        -5.17312765e-01,  1.70886546e-01, -3.67602259e-01, -3.74064833e-01,
#        -3.22570175e-01, -1.03127325e+00, -2.07932994e-01, -3.18191767e-01,
#        -2.13590831e-01, -7.63872802e-01, -1.89659804e-01,  4.96783912e-01,
#         1.85400045e+00,  2.00103331e+00,  2.11445284e+00,  2.88502979e+00,
#         3.54252529e+00,  3.49255347e+00,  2.89464569e+00,  2.58604240e+00,
#         2.06922126e+00,  2.18889093e+00,  1.60308063e+00,  1.80514741e+00,
#         1.19309366e+00,  1.25342870e+00,  1.39275765e+00,  8.37083161e-01,
#         5.32138586e-01,  6.36380076e-01,  2.27088660e-01, -3.32954749e-02,
#         2.63584834e-02,  7.26890713e-02,  5.45429364e-02, -2.63318628e-01,
#        -2.01858327e-01,  3.49268019e-01,  3.29826981e-01, -3.59432288e-02,
#        -9.33106467e-02, -2.54937857e-01,  6.85602892e-03, -1.53221965e-01,
#         6.98004887e-02,  2.67857254e-01,  6.85948074e-01,  5.34359455e-01,
#         4.43424582e-01,  3.02470475e-01,  3.21937501e-01,  2.90707350e-01,
#         3.83676231e-01,  2.61328071e-01,  1.83936402e-01,  2.69367665e-01,
#        -5.17860986e-02, -2.56358683e-02, -1.32234395e-01, -2.85336021e-02,
#         2.00081095e-01,  1.19162239e-01, -1.55313453e-02, -1.54197529e-01],
#       dtype=float32)

# %%
'''
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50, input_shape = dim_entrada))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    tang_hiperbolica
'''
#redes neuronales recurrentes
#Datos son audios convertidos a MFCC 
#mayor accuracy o (porcentaje de aciertos) 


#probando nueva arquitectura
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=120, input_shape=dim_entrada, return_sequences=True))
    model.add(LSTM(units=120, input_shape=dim_entrada, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(LSTM(units=120, input_shape= dim_entrada, return_sequences=False))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
    #model.compile(loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'], optimizer='adam')
    return model

# %%
model = new_RNN()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 120)          58560
#
#  lstm_1 (LSTM)               (None, 120, 120)          115680
#
#  dropout (Dropout)           (None, 120, 120)          0
#
#  activation (Activation)     (None, 120, 120)          0
#
#  lstm_2 (LSTM)               (None, 120)               115680
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  activation_1 (Activation)   (None, 120)               0
#
#  dense (Dense)               (None, 2)                 242
#
# =================================================================
# Total params: 290,162
# Trainable params: 290,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
#50 0.77
model = new_RNN()
#model.summary()
#https://keras.io/api/callbacks/early_stopping/
callbacks = []

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        min_delta=0.01, #si un epochs mejora como un min_delta respecto a la anterior, no contara como mejora
        patience=120,#numero de epochs sin mejoras que se tendra paciencia
        verbose=1,#mostrar informacion extra, 0 no mostrar
     )
]
num_epochs = 80
num_batch_size = 32
start = datetime.datetime.now()
   
results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)
duration = datetime.datetime.now() - start
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
#menor igual a 0.0762
# Out:
# Epoch 1/80
# 40/40 [==============================] - 148s 3s/step - loss: 0.6938 - accuracy: 0.5125 - val_loss: 0.6933 - val_accuracy: 0.4906
# Epoch 2/80
# 40/40 [==============================] - 107s 3s/step - loss: 0.6939 - accuracy: 0.4789 - val_loss: 0.6925 - val_accuracy: 0.5312
# Epoch 3/80
# 40/40 [==============================] - 127s 3s/step - loss: 0.6934 - accuracy: 0.5023 - val_loss: 0.6943 - val_accuracy: 0.4688
# Epoch 4/80
# 40/40 [==============================] - 116s 3s/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6947 - val_accuracy: 0.4688
# Epoch 5/80
# 40/40 [==============================] - 129s 3s/step - loss: 0.6942 - accuracy: 0.4945 - val_loss: 0.6938 - val_accuracy: 0.4688
# Epoch 6/80
# 40/40 [==============================] - 121s 3s/step - loss: 0.6941 - accuracy: 0.4891 - val_loss: 0.6921 - val_accuracy: 0.5312
# Epoch 7/80
# 40/40 [==============================] - 120s 3s/step - loss: 0.6936 - accuracy: 0.5070 - val_loss: 0.6958 - val_accuracy: 0.4656
# Epoch 8/80
# 40/40 [==============================] - 116s 3s/step - loss: 0.6938 - accuracy: 0.5094 - val_loss: 0.6942 - val_accuracy: 0.4688
# Epoch 9/80
# 40/40 [==============================] - 114s 3s/step - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 10/80
# 40/40 [==============================] - 138s 3s/step - loss: 0.6929 - accuracy: 0.5063 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 11/80
# 40/40 [==============================] - 149s 4s/step - loss: 0.6931 - accuracy: 0.5156 - val_loss: 0.6927 - val_accuracy: 0.4812
# Epoch 12/80
# 40/40 [==============================] - 151s 4s/step - loss: 0.6932 - accuracy: 0.4953 - val_loss: 0.6935 - val_accuracy: 0.4969
# Epoch 13/80
# 40/40 [==============================] - 127s 3s/step - loss: 0.6936 - accuracy: 0.5203 - val_loss: 0.6932 - val_accuracy: 0.5156
# Epoch 14/80
# 40/40 [==============================] - 120s 3s/step - loss: 0.6936 - accuracy: 0.5148 - val_loss: 0.6935 - val_accuracy: 0.4938
# Epoch 15/80
# 40/40 [==============================] - 102s 3s/step - loss: 0.6930 - accuracy: 0.5242 - val_loss: 0.6948 - val_accuracy: 0.4844
# Epoch 16/80
# 40/40 [==============================] - 97s 2s/step - loss: 0.6935 - accuracy: 0.5031 - val_loss: 0.6916 - val_accuracy: 0.5094
# Epoch 17/80
# 40/40 [==============================] - 98s 2s/step - loss: 0.6925 - accuracy: 0.5227 - val_loss: 0.6927 - val_accuracy: 0.5125
# Epoch 18/80
# 40/40 [==============================] - 113s 3s/step - loss: 0.6933 - accuracy: 0.5133 - val_loss: 0.6915 - val_accuracy: 0.5063
# Epoch 19/80
# 40/40 [==============================] - 127s 3s/step - loss: 0.6922 - accuracy: 0.5242 - val_loss: 0.6916 - val_accuracy: 0.5281
# Epoch 20/80
# 40/40 [==============================] - 112s 3s/step - loss: 0.6911 - accuracy: 0.5281 - val_loss: 0.6944 - val_accuracy: 0.5094
# Epoch 21/80
# 40/40 [==============================] - 111s 3s/step - loss: 0.6922 - accuracy: 0.5141 - val_loss: 0.6929 - val_accuracy: 0.5281
# Epoch 22/80
# 40/40 [==============================] - 102s 3s/step - loss: 0.6921 - accuracy: 0.5141 - val_loss: 0.6922 - val_accuracy: 0.5125
# Epoch 23/80
# 40/40 [==============================] - 110s 3s/step - loss: 0.6919 - accuracy: 0.5172 - val_loss: 0.6915 - val_accuracy: 0.5156
# Epoch 24/80
# 40/40 [==============================] - 112s 3s/step - loss: 0.6901 - accuracy: 0.5242 - val_loss: 0.6935 - val_accuracy: 0.5219
# Epoch 25/80
# 40/40 [==============================] - 134s 3s/step - loss: 0.6919 - accuracy: 0.5234 - val_loss: 0.6913 - val_accuracy: 0.5156
# Epoch 26/80
# 40/40 [==============================] - 59s 1s/step - loss: 0.6901 - accuracy: 0.5281 - val_loss: 0.6941 - val_accuracy: 0.5188
# Epoch 27/80
# 40/40 [==============================] - 49s 1s/step - loss: 0.6907 - accuracy: 0.5312 - val_loss: 0.6911 - val_accuracy: 0.5125
# Epoch 28/80
# 40/40 [==============================] - 48s 1s/step - loss: 0.6886 - accuracy: 0.5305 - val_loss: 0.6950 - val_accuracy: 0.4969
# Epoch 29/80
# 40/40 [==============================] - 51s 1s/step - loss: 0.6879 - accuracy: 0.5414 - val_loss: 0.6962 - val_accuracy: 0.5125
# Epoch 30/80
# 40/40 [==============================] - 60s 2s/step - loss: 0.6907 - accuracy: 0.5242 - val_loss: 0.6907 - val_accuracy: 0.5156
# Epoch 31/80
# 40/40 [==============================] - 54s 1s/step - loss: 0.6890 - accuracy: 0.5359 - val_loss: 0.6855 - val_accuracy: 0.5562
# Epoch 32/80
# 40/40 [==============================] - 55s 1s/step - loss: 0.6888 - accuracy: 0.5391 - val_loss: 0.6898 - val_accuracy: 0.5375
# Epoch 33/80
# 40/40 [==============================] - 60s 1s/step - loss: 0.6873 - accuracy: 0.5453 - val_loss: 0.6899 - val_accuracy: 0.5156
# Epoch 34/80
# 40/40 [==============================] - 58s 1s/step - loss: 0.6849 - accuracy: 0.5453 - val_loss: 0.6957 - val_accuracy: 0.4969
# Epoch 35/80
# 40/40 [==============================] - 64s 2s/step - loss: 0.6812 - accuracy: 0.5508 - val_loss: 0.6900 - val_accuracy: 0.5156
# Epoch 36/80
# 40/40 [==============================] - 64s 2s/step - loss: 0.6890 - accuracy: 0.5258 - val_loss: 0.6859 - val_accuracy: 0.5250
# Epoch 37/80
# 40/40 [==============================] - 61s 2s/step - loss: 0.6834 - accuracy: 0.5453 - val_loss: 0.6868 - val_accuracy: 0.5094
# Epoch 38/80
# 40/40 [==============================] - 58s 1s/step - loss: 0.6820 - accuracy: 0.5453 - val_loss: 0.6877 - val_accuracy: 0.5219
# Epoch 39/80
# 40/40 [==============================] - 59s 1s/step - loss: 0.6750 - accuracy: 0.5500 - val_loss: 0.6838 - val_accuracy: 0.5156
# Epoch 40/80
# 40/40 [==============================] - 62s 2s/step - loss: 0.6822 - accuracy: 0.5625 - val_loss: 0.6892 - val_accuracy: 0.5188
# Epoch 41/80
# 40/40 [==============================] - 65s 2s/step - loss: 0.6843 - accuracy: 0.5531 - val_loss: 0.6873 - val_accuracy: 0.5031
# Epoch 42/80
# 40/40 [==============================] - 65s 2s/step - loss: 0.6755 - accuracy: 0.5711 - val_loss: 0.6988 - val_accuracy: 0.5219
# Epoch 43/80
# 40/40 [==============================] - 70s 2s/step - loss: 0.6737 - accuracy: 0.5773 - val_loss: 0.6839 - val_accuracy: 0.5469
# Epoch 44/80
# 40/40 [==============================] - 63s 2s/step - loss: 0.6676 - accuracy: 0.5852 - val_loss: 0.6876 - val_accuracy: 0.5312
# Epoch 45/80
# 40/40 [==============================] - 62s 2s/step - loss: 0.6618 - accuracy: 0.6016 - val_loss: 0.6835 - val_accuracy: 0.5437
# Epoch 46/80
# 40/40 [==============================] - 57s 1s/step - loss: 0.6761 - accuracy: 0.5688 - val_loss: 0.6848 - val_accuracy: 0.5469
# Epoch 47/80
# 40/40 [==============================] - 61s 2s/step - loss: 0.6651 - accuracy: 0.5844 - val_loss: 0.6889 - val_accuracy: 0.5156
# Epoch 48/80
# 40/40 [==============================] - 62s 2s/step - loss: 0.6549 - accuracy: 0.6109 - val_loss: 0.6889 - val_accuracy: 0.5844
# Epoch 49/80
# 40/40 [==============================] - 59s 1s/step - loss: 0.6473 - accuracy: 0.6148 - val_loss: 0.6767 - val_accuracy: 0.5406
# Epoch 50/80
# 40/40 [==============================] - 55s 1s/step - loss: 0.6495 - accuracy: 0.5922 - val_loss: 0.6850 - val_accuracy: 0.5375
# Epoch 51/80
# 40/40 [==============================] - 55s 1s/step - loss: 0.6502 - accuracy: 0.6141 - val_loss: 0.6882 - val_accuracy: 0.5844
# Epoch 52/80
# 40/40 [==============================] - 54s 1s/step - loss: 0.6409 - accuracy: 0.6359 - val_loss: 0.6921 - val_accuracy: 0.5625
# Epoch 53/80
# 40/40 [==============================] - 53s 1s/step - loss: 0.6598 - accuracy: 0.5938 - val_loss: 0.6778 - val_accuracy: 0.5781
# Epoch 54/80
# 40/40 [==============================] - 55s 1s/step - loss: 0.6354 - accuracy: 0.6328 - val_loss: 0.6716 - val_accuracy: 0.5688
# Epoch 55/80
# 40/40 [==============================] - 64s 2s/step - loss: 0.6370 - accuracy: 0.6109 - val_loss: 0.6583 - val_accuracy: 0.6344
# Epoch 56/80
# 40/40 [==============================] - 55s 1s/step - loss: 0.6462 - accuracy: 0.6289 - val_loss: 0.6693 - val_accuracy: 0.5750
# Epoch 57/80
# 40/40 [==============================] - 52s 1s/step - loss: 0.6215 - accuracy: 0.6469 - val_loss: 0.6647 - val_accuracy: 0.5813
# Epoch 58/80
# 40/40 [==============================] - 72s 2s/step - loss: 0.6165 - accuracy: 0.6531 - val_loss: 0.6770 - val_accuracy: 0.5531
# Epoch 59/80
# 40/40 [==============================] - 139s 4s/step - loss: 0.6184 - accuracy: 0.6445 - val_loss: 0.6664 - val_accuracy: 0.5969
# Epoch 60/80
# 40/40 [==============================] - 140s 3s/step - loss: 0.5992 - accuracy: 0.6648 - val_loss: 0.6828 - val_accuracy: 0.5500
# Epoch 61/80
# 40/40 [==============================] - 148s 4s/step - loss: 0.6103 - accuracy: 0.6625 - val_loss: 0.6630 - val_accuracy: 0.5969
# Epoch 62/80
# 40/40 [==============================] - 126s 3s/step - loss: 0.5835 - accuracy: 0.6789 - val_loss: 0.6839 - val_accuracy: 0.5938
# Epoch 63/80
# 40/40 [==============================] - 142s 4s/step - loss: 0.5989 - accuracy: 0.6719 - val_loss: 0.6721 - val_accuracy: 0.5969
# Epoch 64/80
# 40/40 [==============================] - 137s 3s/step - loss: 0.5702 - accuracy: 0.6938 - val_loss: 0.6886 - val_accuracy: 0.5906
# Epoch 65/80
# 40/40 [==============================] - 129s 3s/step - loss: 0.5595 - accuracy: 0.6844 - val_loss: 0.6502 - val_accuracy: 0.6562
# Epoch 66/80
# 40/40 [==============================] - 137s 3s/step - loss: 0.5420 - accuracy: 0.7172 - val_loss: 0.6747 - val_accuracy: 0.6219
# Epoch 67/80
# 40/40 [==============================] - 133s 3s/step - loss: 0.5238 - accuracy: 0.7344 - val_loss: 0.6376 - val_accuracy: 0.6344
# Epoch 68/80
# 40/40 [==============================] - 139s 3s/step - loss: 0.5161 - accuracy: 0.7367 - val_loss: 0.6389 - val_accuracy: 0.6438
# Epoch 69/80
# 40/40 [==============================] - 131s 3s/step - loss: 0.5241 - accuracy: 0.7375 - val_loss: 0.6304 - val_accuracy: 0.6375
# Epoch 70/80
# 40/40 [==============================] - 78s 2s/step - loss: 0.4859 - accuracy: 0.7727 - val_loss: 0.6157 - val_accuracy: 0.6938
# Epoch 71/80
# 40/40 [==============================] - 62s 2s/step - loss: 0.4830 - accuracy: 0.7727 - val_loss: 0.6530 - val_accuracy: 0.6406
# Epoch 72/80
# 40/40 [==============================] - 63s 2s/step - loss: 0.4433 - accuracy: 0.7820 - val_loss: 0.6678 - val_accuracy: 0.6812
# Epoch 73/80
# 40/40 [==============================] - 67s 2s/step - loss: 0.4619 - accuracy: 0.7742 - val_loss: 0.6774 - val_accuracy: 0.6438
# Epoch 74/80
# 40/40 [==============================] - 70s 2s/step - loss: 0.4222 - accuracy: 0.8016 - val_loss: 0.7005 - val_accuracy: 0.6562
# Epoch 75/80
# 40/40 [==============================] - 70s 2s/step - loss: 0.4108 - accuracy: 0.8078 - val_loss: 0.6985 - val_accuracy: 0.6750
# Epoch 76/80
# 40/40 [==============================] - 70s 2s/step - loss: 0.4761 - accuracy: 0.7992 - val_loss: 0.6248 - val_accuracy: 0.6844
# Epoch 77/80
# 40/40 [==============================] - 67s 2s/step - loss: 0.3684 - accuracy: 0.8398 - val_loss: 0.6508 - val_accuracy: 0.6969
# Epoch 78/80
# 40/40 [==============================] - 68s 2s/step - loss: 0.4113 - accuracy: 0.8211 - val_loss: 0.6137 - val_accuracy: 0.7156
# Epoch 79/80
# 40/40 [==============================] - 82s 2s/step - loss: 0.3681 - accuracy: 0.8375 - val_loss: 0.6646 - val_accuracy: 0.7000
# Epoch 80/80
# 40/40 [==============================] - 67s 2s/step - loss: 0.3656 - accuracy: 0.8398 - val_loss: 0.6893 - val_accuracy: 0.6781
# val_loss: 0.689315676689148 val_accuracy: 0.6781250238418579
# 10/10 [==============================] - 7s 402ms/step
# El algoritmo acerto 217 veces sobre los 320 casos.

# %%
 training_loss = results.history['loss']
test_loss = results.history['val_loss']
epochs_range = range(1, len(training_loss) + 1)

# %%
plt.plot(epochs_range, training_loss, 'r',marker="o",linestyle="--")
plt.plot(epochs_range, test_loss, 'b',marker="o",linestyle="-")
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.rcParams["figure.figsize"] = (20,8)
plt.grid()
plt.show()

# %%
k_fold = KFold(5)
fold = 0
y_tests = []
predictions = []
scores = []
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))
for train, test in k_fold.split(X):
    fold = fold + 1
    print(f"Fold #{fold}")
    X_train = X[train]
    X_test = X[test]
    y_train = y[train]
    y_test = y[test]
    print(f"Train - X:{X_train.shape} y:{y_train.shape}")
    print(f"Test - X:{X_test.shape} y:{y_test.shape}")
    
    num_labels = y.shape[1]
    dim_entrada = (X_train.shape[1],1)

    #model = new_RNN()
    model = new_RNN()
    callbacks = []
    '''
    callbacks = [
    EarlyStopping(
            monitor="val_loss",
            min_delta=1e-2,
            patience=20,
            verbose=1,
        )
    ]
    '''
    num_epochs = 65
    num_batch_size = 32
    start = datetime.datetime.now()
   
    results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)

    pred = model.predict(X_test)
    y_tests.append(y_test)
    pred=[([1,0] if i[0]>i[1] else [0,1]) for i in pred]
    predictions.append(pred)
    score = metrics.accuracy_score(pred, y_test)
    math = confusion_matrix([(1 if x[0]==1 else 0) for x in pred],[(1 if x[0]==1 else 0) for x in y_test], labels=[1,0])
    scores.append([score])
    print(f"Fold score (Accuracy score): {score}")
    print("Matriz de confusion")
    print("-------------------")
    print("---------| Verdadero | Falso |")
    print(f"Verdadero|  {math[0][0]}        {math[0][1]}")
    print(f"Falso    |  {math[1][0]}        {math[1][1]}")

y_tests = np.concatenate(y_tests)
predictions = np.concatenate(predictions)
score = metrics.accuracy_score(predictions, y_tests)
print("-----------------------")
print(f"Cross-validated score (Accuracy score): {score}")
print("-----------------------")
print("Resumen")
for result in scores:
    print(f"Fold score (Accuracy score): {result[0]}")
    
#https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_05_2_kfold.ipynb
#https://www.youtube.com/watch?v=maiQf8ray_s
# Out:
# Fold #1
# Train - X:(1280, 128) y:(1280, 2)
# Test - X:(320, 128) y:(320, 2)
# Epoch 1/65
# 40/40 [==============================] - 176s 4s/step - loss: 0.6952 - accuracy: 0.5016 - val_loss: 0.6908 - val_accuracy: 0.5375
# Epoch 2/65
# 40/40 [==============================] - 155s 4s/step - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6945 - val_accuracy: 0.4844
# Epoch 3/65
# 40/40 [==============================] - 164s 4s/step - loss: 0.6961 - accuracy: 0.5109 - val_loss: 0.6993 - val_accuracy: 0.4594
# Epoch 4/65
# 40/40 [==============================] - 165s 4s/step - loss: 0.6926 - accuracy: 0.5156 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 5/65
# 40/40 [==============================] - 178s 4s/step - loss: 0.6913 - accuracy: 0.5305 - val_loss: 0.6977 - val_accuracy: 0.4781
# Epoch 6/65
# 40/40 [==============================] - 157s 4s/step - loss: 0.6940 - accuracy: 0.5227 - val_loss: 0.6935 - val_accuracy: 0.5063
# Epoch 7/65
# 40/40 [==============================] - 159s 4s/step - loss: 0.6920 - accuracy: 0.5219 - val_loss: 0.6940 - val_accuracy: 0.4906
# Epoch 8/65
# 40/40 [==============================] - 152s 4s/step - loss: 0.6930 - accuracy: 0.5195 - val_loss: 0.6927 - val_accuracy: 0.5188
# Epoch 9/65
# 40/40 [==============================] - 170s 4s/step - loss: 0.6910 - accuracy: 0.5266 - val_loss: 0.6928 - val_accuracy: 0.5063
# Epoch 10/65
# 40/40 [==============================] - 192s 5s/step - loss: 0.6935 - accuracy: 0.5328 - val_loss: 0.6933 - val_accuracy: 0.5031
# Epoch 11/65
# 40/40 [==============================] - 183s 5s/step - loss: 0.6928 - accuracy: 0.5188 - val_loss: 0.7004 - val_accuracy: 0.4594
# Epoch 12/65
# 40/40 [==============================] - 182s 5s/step - loss: 0.6921 - accuracy: 0.5234 - val_loss: 0.6935 - val_accuracy: 0.5250
# Epoch 13/65
# 40/40 [==============================] - 171s 4s/step - loss: 0.6906 - accuracy: 0.5188 - val_loss: 0.6929 - val_accuracy: 0.4938
# Epoch 14/65
# 40/40 [==============================] - 132s 3s/step - loss: 0.6922 - accuracy: 0.5227 - val_loss: 0.6906 - val_accuracy: 0.5156
# Epoch 15/65
# 40/40 [==============================] - 131s 3s/step - loss: 0.6903 - accuracy: 0.5312 - val_loss: 0.6942 - val_accuracy: 0.5031
# Epoch 16/65
# 40/40 [==============================] - 143s 4s/step - loss: 0.6897 - accuracy: 0.5258 - val_loss: 0.6975 - val_accuracy: 0.4781
# Epoch 17/65
# 40/40 [==============================] - 138s 3s/step - loss: 0.6885 - accuracy: 0.5398 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 18/65
# 40/40 [==============================] - 131s 3s/step - loss: 0.6924 - accuracy: 0.5039 - val_loss: 0.6922 - val_accuracy: 0.5281
# Epoch 19/65
# 40/40 [==============================] - 134s 3s/step - loss: 0.6905 - accuracy: 0.5289 - val_loss: 0.6939 - val_accuracy: 0.5219
# Epoch 20/65
# 40/40 [==============================] - 141s 4s/step - loss: 0.6881 - accuracy: 0.5461 - val_loss: 0.6876 - val_accuracy: 0.5375
# Epoch 21/65
# 40/40 [==============================] - 138s 3s/step - loss: 0.6896 - accuracy: 0.5242 - val_loss: 0.6940 - val_accuracy: 0.5188
# Epoch 22/65
# 40/40 [==============================] - 143s 4s/step - loss: 0.6894 - accuracy: 0.5180 - val_loss: 0.6926 - val_accuracy: 0.5188
# Epoch 23/65
# 40/40 [==============================] - 148s 4s/step - loss: 0.6898 - accuracy: 0.5242 - val_loss: 0.6924 - val_accuracy: 0.4969
# Epoch 24/65
# 40/40 [==============================] - 135s 3s/step - loss: 0.6879 - accuracy: 0.5477 - val_loss: 0.6898 - val_accuracy: 0.5375
# Epoch 25/65
# 40/40 [==============================] - 155s 4s/step - loss: 0.6869 - accuracy: 0.5625 - val_loss: 0.6887 - val_accuracy: 0.5500
# Epoch 26/65
# 40/40 [==============================] - 152s 4s/step - loss: 0.6882 - accuracy: 0.5258 - val_loss: 0.6941 - val_accuracy: 0.5344
# Epoch 27/65
# 40/40 [==============================] - 154s 4s/step - loss: 0.6865 - accuracy: 0.5266 - val_loss: 0.6908 - val_accuracy: 0.5000
# Epoch 28/65
# 40/40 [==============================] - 151s 4s/step - loss: 0.6868 - accuracy: 0.5305 - val_loss: 0.6908 - val_accuracy: 0.5125
# Epoch 29/65
# 40/40 [==============================] - 151s 4s/step - loss: 0.6887 - accuracy: 0.5492 - val_loss: 0.6928 - val_accuracy: 0.4969
# Epoch 30/65
# 40/40 [==============================] - 157s 4s/step - loss: 0.6847 - accuracy: 0.5477 - val_loss: 0.6898 - val_accuracy: 0.5156
# Epoch 31/65
# 40/40 [==============================] - 143s 4s/step - loss: 0.6913 - accuracy: 0.5375 - val_loss: 0.6970 - val_accuracy: 0.5250
# Epoch 32/65
# 40/40 [==============================] - 148s 4s/step - loss: 0.6858 - accuracy: 0.5484 - val_loss: 0.6903 - val_accuracy: 0.5531
# Epoch 33/65
# 40/40 [==============================] - 157s 4s/step - loss: 0.6928 - accuracy: 0.5117 - val_loss: 0.6917 - val_accuracy: 0.5500
# Epoch 34/65
# 40/40 [==============================] - 161s 4s/step - loss: 0.6868 - accuracy: 0.5367 - val_loss: 0.6956 - val_accuracy: 0.5125
# Epoch 35/65
# 40/40 [==============================] - 159s 4s/step - loss: 0.6846 - accuracy: 0.5383 - val_loss: 0.6980 - val_accuracy: 0.4938
# Epoch 36/65
# 40/40 [==============================] - 157s 4s/step - loss: 0.6874 - accuracy: 0.5383 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 37/65
# 40/40 [==============================] - 147s 4s/step - loss: 0.6831 - accuracy: 0.5609 - val_loss: 0.6907 - val_accuracy: 0.4969
# Epoch 38/65
# 40/40 [==============================] - 153s 4s/step - loss: 0.6838 - accuracy: 0.5461 - val_loss: 0.6880 - val_accuracy: 0.5656
# Epoch 39/65
# 40/40 [==============================] - 164s 4s/step - loss: 0.6858 - accuracy: 0.5344 - val_loss: 0.6887 - val_accuracy: 0.5219
# Epoch 40/65
# 40/40 [==============================] - 137s 3s/step - loss: 0.6847 - accuracy: 0.5344 - val_loss: 0.6938 - val_accuracy: 0.5469
# Epoch 41/65
# 40/40 [==============================] - 66s 2s/step - loss: 0.6838 - accuracy: 0.5617 - val_loss: 0.6989 - val_accuracy: 0.5156
# Epoch 42/65
# 40/40 [==============================] - 67s 2s/step - loss: 0.6864 - accuracy: 0.5586 - val_loss: 0.6994 - val_accuracy: 0.5031
# Epoch 43/65
# 40/40 [==============================] - 72s 2s/step - loss: 0.6814 - accuracy: 0.5422 - val_loss: 0.6765 - val_accuracy: 0.5750
# Epoch 44/65
# 40/40 [==============================] - 72s 2s/step - loss: 0.7202 - accuracy: 0.5188 - val_loss: 0.6921 - val_accuracy: 0.5437
# Epoch 45/65
# 40/40 [==============================] - 74s 2s/step - loss: 0.7089 - accuracy: 0.4906 - val_loss: 0.6922 - val_accuracy: 0.5437
# Epoch 46/65
# 40/40 [==============================] - 74s 2s/step - loss: 0.6976 - accuracy: 0.4953 - val_loss: 0.6942 - val_accuracy: 0.4563
# Epoch 47/65
# 40/40 [==============================] - 76s 2s/step - loss: 0.6947 - accuracy: 0.5266 - val_loss: 0.6911 - val_accuracy: 0.5437
# Epoch 48/65
# 40/40 [==============================] - 84s 2s/step - loss: 0.6957 - accuracy: 0.5000 - val_loss: 0.6990 - val_accuracy: 0.4563
# Epoch 49/65
# 40/40 [==============================] - 77s 2s/step - loss: 0.6970 - accuracy: 0.4867 - val_loss: 0.6988 - val_accuracy: 0.4563
# Epoch 50/65
# 40/40 [==============================] - 78s 2s/step - loss: 0.6964 - accuracy: 0.4781 - val_loss: 0.6965 - val_accuracy: 0.4563
# Epoch 51/65
# 40/40 [==============================] - 82s 2s/step - loss: 0.6953 - accuracy: 0.4852 - val_loss: 0.6934 - val_accuracy: 0.4563
# Epoch 52/65
# 40/40 [==============================] - 87s 2s/step - loss: 0.6949 - accuracy: 0.5125 - val_loss: 0.6958 - val_accuracy: 0.4563
# Epoch 53/65
# 40/40 [==============================] - 79s 2s/step - loss: 0.6956 - accuracy: 0.4789 - val_loss: 0.6964 - val_accuracy: 0.4563
# Epoch 54/65
# 40/40 [==============================] - 81s 2s/step - loss: 0.6940 - accuracy: 0.4945 - val_loss: 0.6964 - val_accuracy: 0.4563
# Epoch 55/65
# 40/40 [==============================] - 74s 2s/step - loss: 0.6955 - accuracy: 0.5055 - val_loss: 0.6946 - val_accuracy: 0.4563
# Epoch 56/65
# 40/40 [==============================] - 79s 2s/step - loss: 0.6930 - accuracy: 0.5148 - val_loss: 0.6953 - val_accuracy: 0.4563
# Epoch 57/65
# 40/40 [==============================] - 86s 2s/step - loss: 0.6941 - accuracy: 0.5016 - val_loss: 0.6960 - val_accuracy: 0.4563
# Epoch 58/65
# 40/40 [==============================] - 83s 2s/step - loss: 0.6931 - accuracy: 0.4992 - val_loss: 0.6940 - val_accuracy: 0.4563
# Epoch 59/65
# 40/40 [==============================] - 92s 2s/step - loss: 0.6931 - accuracy: 0.5172 - val_loss: 0.6945 - val_accuracy: 0.4563
# Epoch 60/65
# 40/40 [==============================] - 81s 2s/step - loss: 0.6946 - accuracy: 0.4727 - val_loss: 0.6955 - val_accuracy: 0.4563
# Epoch 61/65
# 40/40 [==============================] - 94s 2s/step - loss: 0.6931 - accuracy: 0.4992 - val_loss: 0.6939 - val_accuracy: 0.4563
# Epoch 62/65
# 40/40 [==============================] - 88s 2s/step - loss: 0.6924 - accuracy: 0.5195 - val_loss: 0.6959 - val_accuracy: 0.4563
# Epoch 63/65
# 40/40 [==============================] - 82s 2s/step - loss: 0.6936 - accuracy: 0.5141 - val_loss: 0.6954 - val_accuracy: 0.4563
# Epoch 64/65
# 40/40 [==============================] - 74s 2s/step - loss: 0.6932 - accuracy: 0.5086 - val_loss: 0.6941 - val_accuracy: 0.4563
# Epoch 65/65
# 40/40 [==============================] - 82s 2s/step - loss: 0.6939 - accuracy: 0.4859 - val_loss: 0.6944 - val_accuracy: 0.4563
# 10/10 [==============================] - 12s 203ms/step
# Fold score (Accuracy score): 0.45625
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  0        0
# Falso    |  174        146
# Fold #2
# Train - X:(1280, 128) y:(1280, 2)
# Test - X:(320, 128) y:(320, 2)
# Epoch 1/65
# 40/40 [==============================] - 178s 4s/step - loss: 0.6943 - accuracy: 0.5016 - val_loss: 0.6912 - val_accuracy: 0.5281
# Epoch 2/65
# 40/40 [==============================] - 181s 5s/step - loss: 0.6942 - accuracy: 0.4977 - val_loss: 0.6922 - val_accuracy: 0.5156
# Epoch 3/65
# 40/40 [==============================] - 172s 4s/step - loss: 0.6932 - accuracy: 0.5086 - val_loss: 0.6916 - val_accuracy: 0.5094
# Epoch 4/65
# 40/40 [==============================] - 169s 4s/step - loss: 0.6930 - accuracy: 0.5125 - val_loss: 0.6920 - val_accuracy: 0.5094
# Epoch 5/65
# 40/40 [==============================] - 187s 5s/step - loss: 0.6941 - accuracy: 0.5156 - val_loss: 0.6920 - val_accuracy: 0.5188
# Epoch 6/65
# 40/40 [==============================] - 191s 5s/step - loss: 0.6925 - accuracy: 0.5078 - val_loss: 0.6927 - val_accuracy: 0.5094
# Epoch 7/65
# 40/40 [==============================] - 175s 4s/step - loss: 0.6933 - accuracy: 0.5094 - val_loss: 0.6924 - val_accuracy: 0.5063
# Epoch 8/65
# 36/40 [==========================>...] - ETA: 16s - loss: 0.6922 - accuracy: 0.5130

# %%
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")

y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
    
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# val_loss: 0.7011466026306152 val_accuracy: 0.637499988079071
# El algoritmo acerto 240 veces sobre los 320 casos.

# %%
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model

'''
Cross-validated score (Accuracy score): 0.8200663349917081
-----------------------
Resumen
Fold score (Accuracy score): 0.8281573498964804
Fold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687
Fold score (Accuracy score): 0.8008298755186722
Fold score (Accuracy score): 0.8174273858921162
Fold score (Accuracy score): 0.8112033195020747
'''
# Out:
# '\nCross-validated score (Accuracy score): 0.8200663349917081\n-----------------------\nResumen\nFold score (Accuracy score): 0.8281573498964804\nFold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687\nFold score (Accuracy score): 0.8008298755186722\nFold score (Accuracy score): 0.8174273858921162\nFold score (Accuracy score): 0.8112033195020747\n'

# %%
'''
val_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128
val_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128
val_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808
'''
# Out:
# '\nval_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128\nval_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128\nval_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808\n'

# %% [markdown]
# #### Crossvalidation

# %%
X = np.array(X)
y = np.array(y)
print(f"X:{X.shape} y:{y.shape}")
# Out:
# X:(2236, 40) y:(2236, 2)

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# El bloque realizara el k fold cross validation dividiendolo en 5 folds, se uso los MSE.

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_5.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
