# %% [markdown]
# ## Antiguo proyecto de Redes Neuronales Recurrentes usando audios .wav, obteniendo su MFCC, aplicandolos a una RNN y validandolo con k fold cross validation

# %% [markdown]
# #### Librerias

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display
import os
import soundfile as sf
import json
import random
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np

from keras import Sequential
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed

import datetime
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
random.seed(0)

# %% [markdown]
# #### Funciones a usar

# %%
#Obtiene el path con el nombre de todos los archivos de un directorio.
def get_files_from_path(directory):
    path_files = []
    dir_list = os.listdir(directory)
    for path in dir_list:
        path_files.append(directory+"\\"+path)
    return path_files


#Extrae los paths que cumplan con un codigo
def extract_paths_for_emotions_keys(emotions_code, files_path, get_code):
    paths = []
    emotions_set = set(emotions_code)
    for code_file in files_path:
        if (get_code(code_file) in emotions_set):
            paths.append(code_file)
    return paths


#Obtiene el codigo en el nombre del archivo para el dataset CREMA-D
def get_code_esp(path):
    return path[114]#path[110] prueba

def scaled_datas(X):
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled

#Esta función abre el archivo .wav y obtiene el mfcc escalado en un vector de 40 elementos.
def features_extractor(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except:
        print("rrrr-", file_name)


#Esta función permite guardar los MFCC en 'features', el código en 'code' y su dirección en 'path' en un archivo json. 
def save_elements_in_json(examples_saved, name):
    json_files = []
    json_file = {}
    index = 0
    for file in examples_saved:
        json_file = {"id": index, "features":[str(elem) for elem in file[0]] ,"code":file[1], "path":file[2]}
        json_files.append(json_file)
        index += 1
    json_object = json.dumps(json_files)
    with open(f"{name}.json", "w") as outfile:
        outfile.write(json_object)
   

#La función permite cargar datos del MFCC y código desde un archivo json.
def load_elements_from_json(name):
    f = open(f'{name}.json')
    data = json.load(f)
    examples = []
    for element in data:
        examples.append(([float(feature) for feature in (element["features"])], element["code"]))
    return examples


#La función nos permite devolver una lista de MFCC obtenidos de una lista de paths. 
#El MFCC tiene un límite que no le permite cargar archivos menor o igual a 44 kb.
#Con el diccionario obtenemos el total de audios recuperados por emoción.
def get_features(paths,get_code, files_filters = dict()):
    examples = []
    for path in paths:
        code = get_code(path)
        file_stats = os.stat(path)
        feature = features_extractor(path)
        files_filters[code]+= 1
        examples.append((feature,code))
    print(f"Se obtuvo el MFCC de unos {len(paths)} sobre {sum(files_filters[files] for files in files_filters)} audios.")
    return examples


#Selecciona n ejemplos que necesitemos y los mezcla.
def select_elements(examples, code, quantity, new_code):
    random.shuffle(examples)
    elements = []
    counter = 1
    for example in examples:
        if (counter > quantity):
            break
        if code == example[1]:
            elements.append((example[0],new_code))
            counter = counter + 1
    return elements

# %% [markdown]
# Los siguientes bloques obtienen los paths y filtra las emociones que necesitemos en cada dataset (CREMA-D y SAVEE).

# %% [markdown]
# #### Funciones para obtener los datos

# %%
#Obtiene todos los datos de CREMA-D y SAVEE para un  
def get_datas():
    files_path = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\data")
    emotions_code = ["t", "f"]
    datas_files = extract_paths_for_emotions_keys(emotions_code, files_path, get_code_esp)
    examples = []
    files_filters = dict()
    files_filters["t"] = 0
    files_filters["f"] = 0
    examples = get_features(datas_files, get_code_esp, files_filters)
    return examples

#Obtiene los datos de entrada para la red neuronal x: mfcc normalizados, y: labeles categorizados
def get_entries():
    all_examples = get_datas()
    entries = []
    for example in all_examples:
        entries.append((example[0], example[1]))
    datas = select_elements(entries, 't', 800,"without_stress")
    datas += select_elements(entries, 'f', 800, "stress")
    random.shuffle(datas)
    X = []
    y = []
    for data in datas:
        X.append(data[0])
        y.append(data[1])
    labelencoder=preprocessing.LabelEncoder()
    y = to_categorical(labelencoder.fit_transform(y))
    return X, y

#Obtiene los datos divididos de entrenamiento y tests
def obtain_datas_train_and_test(percentage):
    X, y = get_entries()
    
    X_test, X_train, y_test, y_train = train_test_split(X, y, test_size =percentage,random_state=0)
    y = np.array(y)
    X_train = np.array(X_train)
    X_test = np.array(X_test)
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = obtain_datas_train_and_test(0.8)
num_labels = y_train.shape[1] + y_test.shape[1]
dim_entrada = (X_train.shape[1],1)
# Out:
# Se obtuvo el MFCC de unos 1600 sobre 1600 audios.

# %%
X_train[0]
# Out:
# array([-2.03619125e+02,  1.32924957e+02,  1.16074324e+01,  4.22039948e+01,
#         1.59348106e+01,  1.00078325e+01,  3.09595966e+00,  9.74628162e+00,
#        -6.43884420e+00,  5.50276041e+00, -3.89752269e+00,  3.09939122e+00,
#         1.09478855e+00,  3.97362924e+00,  1.78057158e+00,  6.92045116e+00,
#         9.58635986e-01,  1.92379892e+00,  1.48452592e+00, -2.62816620e+00,
#        -3.95873570e+00,  1.12830214e-01, -7.04381943e+00, -3.05793919e-02,
#        -4.39929628e+00,  6.19296312e-01, -3.25743532e+00, -2.55520612e-01,
#        -6.84725106e-01, -8.80580246e-01,  2.59195876e+00, -2.84970117e+00,
#        -1.94983974e-01, -3.07813001e+00, -1.43103153e-01, -1.69904196e+00,
#        -7.15058565e-01, -6.39670566e-02, -1.59365737e+00, -6.24961972e-01],
#       dtype=float32)

# %%
'''
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50, input_shape = dim_entrada))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    tang_hiperbolica
'''
#redes neuronales recurrentes
#Datos son audios convertidos a MFCC 
#mayor accuracy o (porcentaje de aciertos) 


#probando nueva arquitectura
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=True))
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=True))
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

    return model

# %%
model = new_RNN()
model.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_64 (LSTM)              (None, 40, 50)            10400
#
#  lstm_65 (LSTM)              (None, 40, 50)            20200
#
#  lstm_66 (LSTM)              (None, 50)                20200
#
#  activation_60 (Activation)  (None, 50)                0
#
#  dropout_54 (Dropout)        (None, 50)                0
#
#  dense_41 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 50,902
# Trainable params: 50,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
#50 0.77
model = new_RNN()
model.summary()
#https://keras.io/api/callbacks/early_stopping/
callbacks = []
'''
callbacks = [
    EarlyStopping(
        monitor="val_accuracy",
        min_delta=0.01, #si un epochs mejora como un min_delta respecto a la anterior, no contara como mejora
        patience=70,#numero de epochs sin mejoras que se tendra paciencia
        verbose=1,#mostrar informacion extra, 0 no mostrar
     )
]
'''
num_epochs = 100
num_batch_size = 32
start = datetime.datetime.now()
   
results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)
duration = datetime.datetime.now() - start
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_67 (LSTM)              (None, 40, 50)            10400
#
#  lstm_68 (LSTM)              (None, 40, 50)            20200
#
#  lstm_69 (LSTM)              (None, 50)                20200
#
#  activation_61 (Activation)  (None, 50)                0
#
#  dropout_55 (Dropout)        (None, 50)                0
#
#  dense_42 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 50,902
# Trainable params: 50,902
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 40/40 [==============================] - 10s 126ms/step - loss: 0.6944 - accuracy: 0.5297 - val_loss: 0.6930 - val_accuracy: 0.5219
# Epoch 2/100
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6973 - accuracy: 0.5008 - val_loss: 0.6935 - val_accuracy: 0.5344
# Epoch 3/100
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6968 - accuracy: 0.5141 - val_loss: 0.6966 - val_accuracy: 0.4656
# Epoch 4/100
# 40/40 [==============================] - 3s 77ms/step - loss: 0.6948 - accuracy: 0.5016 - val_loss: 0.6923 - val_accuracy: 0.5125
# Epoch 5/100
# 40/40 [==============================] - 3s 78ms/step - loss: 0.6947 - accuracy: 0.4898 - val_loss: 0.6958 - val_accuracy: 0.4594
# Epoch 85/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3100 - accuracy: 0.8492 - val_loss: 0.6531 - val_accuracy: 0.6938
# Epoch 86/100
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3552 - accuracy: 0.8125 - val_loss: 0.6863 - val_accuracy: 0.7250
# Epoch 87/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2987 - accuracy: 0.8672 - val_loss: 0.6525 - val_accuracy: 0.7406
# Epoch 88/100
# 40/40 [==============================] - 4s 92ms/step - loss: 0.2633 - accuracy: 0.8703 - val_loss: 0.7387 - val_accuracy: 0.7469
# Epoch 89/100
# 40/40 [==============================] - 3s 82ms/step - loss: 0.2571 - accuracy: 0.8734 - val_loss: 0.7068 - val_accuracy: 0.7500
# Epoch 90/100
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3152 - accuracy: 0.8477 - val_loss: 0.7712 - val_accuracy: 0.7094
# Epoch 91/100
# 40/40 [==============================] - 3s 86ms/step - loss: 0.2984 - accuracy: 0.8477 - val_loss: 0.7224 - val_accuracy: 0.7437
# Epoch 92/100
# 40/40 [==============================] - 3s 85ms/step - loss: 0.2397 - accuracy: 0.8969 - val_loss: 0.7017 - val_accuracy: 0.7531
# Epoch 93/100
# 40/40 [==============================] - 5s 121ms/step - loss: 0.2189 - accuracy: 0.8922 - val_loss: 0.6778 - val_accuracy: 0.7469
# Epoch 94/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.1924 - accuracy: 0.9117 - val_loss: 0.7065 - val_accuracy: 0.7688
# Epoch 95/100
# 40/40 [==============================] - 4s 103ms/step - loss: 0.2266 - accuracy: 0.8977 - val_loss: 0.7406 - val_accuracy: 0.7375
# Epoch 96/100
# 40/40 [==============================] - 3s 85ms/step - loss: 0.2488 - accuracy: 0.8883 - val_loss: 0.9091 - val_accuracy: 0.7188
# Epoch 97/100
# 40/40 [==============================] - 3s 85ms/step - loss: 0.2516 - accuracy: 0.8852 - val_loss: 0.7398 - val_accuracy: 0.7500
# Epoch 98/100
# 40/40 [==============================] - 3s 67ms/step - loss: 0.2059 - accuracy: 0.8992 - val_loss: 0.7249 - val_accuracy: 0.7781
# Epoch 99/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.1888 - accuracy: 0.9102 - val_loss: 0.8579 - val_accuracy: 0.7375
# Epoch 100/100
# 40/40 [==============================] - 4s 105ms/step - loss: 0.1660 - accuracy: 0.9187 - val_loss: 0.8067 - val_accuracy: 0.7812
# val_loss: 0.8066943287849426 val_accuracy: 0.78125
# 10/10 [==============================] - 2s 29ms/step
# El algoritmo acerto 250 veces sobre los 320 casos.

# %%
training_loss = results.history['loss']
test_loss = results.history['val_loss']
epochs_range = range(1, len(training_loss) + 1)

# %%
plt.plot(epochs_range, training_loss, 'r',marker="o",linestyle="--")
plt.plot(epochs_range, test_loss, 'b',marker="o",linestyle="-")
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.rcParams["figure.figsize"] = (20,8)
plt.grid()
plt.show()

# %%
k_fold = KFold(5)
fold = 0
y_tests = []
predictions = []
scores = []
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))
for train, test in k_fold.split(X):
    fold = fold + 1
    print(f"Fold #{fold}")
    X_train = X[train]
    X_test = X[test]
    y_train = y[train]
    y_test = y[test]
    print(f"Train - X:{X_train.shape} y:{y_train.shape}")
    print(f"Test - X:{X_test.shape} y:{y_test.shape}")
    
    num_labels = y.shape[1]
    dim_entrada = (X_train.shape[1],1)

    #model = new_RNN()
    model = new_RNN()
    callbacks = []
    '''
    callbacks = [
    EarlyStopping(
            monitor="val_loss",
            min_delta=1e-2,
            patience=20,
            verbose=1,
        )
    ]
    '''
    num_epochs = 60
    num_batch_size = 32
    start = datetime.datetime.now()
   
    results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)

    pred = model.predict(X_test)
    y_tests.append(y_test)
    pred=[([1,0] if i[0]>i[1] else [0,1]) for i in pred]
    predictions.append(pred)
    score = metrics.accuracy_score(pred, y_test)
    math = confusion_matrix([(1 if x[0]==1 else 0) for x in pred],[(1 if x[0]==1 else 0) for x in y_test], labels=[1,0])
    scores.append([score])
    print(f"Fold score (Accuracy score): {score}")
    print("Matriz de confusion")
    print("-------------------")
    print("---------| Verdadero | Falso |")
    print(f"Verdadero|  {math[0][0]}        {math[0][1]}")
    print(f"Falso    |  {math[1][0]}        {math[1][1]}")

y_tests = np.concatenate(y_tests)
predictions = np.concatenate(predictions)
score = metrics.accuracy_score(predictions, y_tests)
print("-----------------------")
print(f"Cross-validated score (Accuracy score): {score}")
print("-----------------------")
print("Resumen")
for result in scores:
    print(f"Fold score (Accuracy score): {result[0]}")
    
#https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_05_2_kfold.ipynb
#https://www.youtube.com/watch?v=maiQf8ray_s
# Out:
# Fold #1
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 11s 127ms/step - loss: 0.6963 - accuracy: 0.5063 - val_loss: 0.6944 - val_accuracy: 0.4656
# Epoch 2/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6949 - accuracy: 0.5094 - val_loss: 0.7040 - val_accuracy: 0.4500
# Epoch 3/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6928 - accuracy: 0.5180 - val_loss: 0.6980 - val_accuracy: 0.4344
# Epoch 4/60
# 40/40 [==============================] - 3s 77ms/step - loss: 0.6942 - accuracy: 0.5031 - val_loss: 0.6977 - val_accuracy: 0.4375
# Epoch 5/60
# 40/40 [==============================] - 3s 79ms/step - loss: 0.6921 - accuracy: 0.5266 - val_loss: 0.6999 - val_accuracy: 0.4313
# Epoch 6/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6910 - accuracy: 0.5109 - val_loss: 0.6990 - val_accuracy: 0.4344
# Epoch 7/60
# 40/40 [==============================] - 3s 77ms/step - loss: 0.6926 - accuracy: 0.5047 - val_loss: 0.7001 - val_accuracy: 0.4406
60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6148 - accuracy: 0.6352 - val_loss: 0.7011 - val_accuracy: 0.5875
# Epoch 51/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6070 - accuracy: 0.6383 - val_loss: 0.7059 - val_accuracy: 0.5375
# Epoch 52/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5848 - accuracy: 0.6586 - val_loss: 0.6901 - val_accuracy: 0.5906
# Epoch 53/60
# 40/40 [==============================] - 4s 104ms/step - loss: 0.5999 - accuracy: 0.6461 - val_loss: 0.7193 - val_accuracy: 0.5781
# Epoch 54/60
# 40/40 [==============================] - 5s 132ms/step - loss: 0.6184 - accuracy: 0.6469 - val_loss: 0.7193 - val_accuracy: 0.5594
# Epoch 55/60
# 40/40 [==============================] - 5s 121ms/step - loss: 0.5862 - accuracy: 0.6758 - val_loss: 0.6953 - val_accuracy: 0.5813
# Epoch 56/60
# 40/40 [==============================] - 5s 118ms/step - loss: 0.5752 - accuracy: 0.6828 - val_loss: 0.6901 - val_accuracy: 0.6031
# Epoch 57/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5769 - accuracy: 0.6648 - val_loss: 0.6802 - val_accuracy: 0.6125
# Epoch 58/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.5643 - accuracy: 0.6859 - val_loss: 0.6826 - val_accuracy: 0.5906
# Epoch 59/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.5528 - accuracy: 0.7055 - val_loss: 0.6628 - val_accuracy: 0.6250
# Epoch 60/60
# 40/40 [==============================] - 4s 104ms/step - loss: 0.5423 - accuracy: 0.6945 - val_loss: 0.7069 - val_accuracy: 0.6000
# 10/10 [==============================] - 3s 34ms/step
# Fold score (Accuracy score): 0.6
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  96        50
# Falso    |  78        96
# Fold #2
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 11s 144ms/step - loss: 0.6957 - accuracy: 0.4906 - val_loss: 0.6951 - val_accuracy: 0.5000
# Epoch 2/60
# 40/40 [==============================] - 3s 76ms/step - loss: 0.6982 - accuracy: 0.4867 - val_loss: 0.6933 - val_accuracy: 0.4906
# Epoch 3/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6930 - accuracy: 0.5172 - val_loss: 0.6926 - val_accuracy: 0.4969
# Epoch 4/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6952 - accuracy: 0.4898 - val_loss: 0.6944 - val_accuracy: 0.4969
# Epoch 5/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6944 - accuracy: 0.5109 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch
60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6378 - accuracy: 0.6141 - val_loss: 0.7022 - val_accuracy: 0.5375
# Epoch 45/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6284 - accuracy: 0.6211 - val_loss: 0.6936 - val_accuracy: 0.5125
# Epoch 46/60
# 40/40 [==============================] - 4s 99ms/step - loss: 0.6220 - accuracy: 0.6086 - val_loss: 0.7243 - val_accuracy: 0.5500
# Epoch 47/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.6061 - accuracy: 0.6258 - val_loss: 0.7278 - val_accuracy: 0.5344
# Epoch 48/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6154 - accuracy: 0.6562 - val_loss: 0.7226 - val_accuracy: 0.5281
# Epoch 49/60
# 40/40 [==============================] - 4s 100ms/step - loss: 0.6065 - accuracy: 0.6375 - val_loss: 0.7065 - val_accuracy: 0.5469
# Epoch 50/60
# 40/40 [==============================] - 3s 88ms/step - loss: 0.5891 - accuracy: 0.6641 - val_loss: 0.7375 - val_accuracy: 0.5188
# Epoch 51/60
# 40/40 [==============================] - 5s 129ms/step - loss: 0.5776 - accuracy: 0.6625 - val_loss: 0.7346 - val_accuracy: 0.5813
# Epoch 52/60
# 40/40 [==============================] - 5s 129ms/step - loss: 0.5881 - accuracy: 0.6508 - val_loss: 0.7038 - val_accuracy: 0.5844
# Epoch 53/60
# 40/40 [==============================] - 5s 118ms/step - loss: 0.5742 - accuracy: 0.6648 - val_loss: 0.7199 - val_accuracy: 0.5750
# Epoch 54/60
# 40/40 [==============================] - 5s 121ms/step - loss: 0.5693 - accuracy: 0.6789 - val_loss: 0.7368 - val_accuracy: 0.5719
# Epoch 55/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.5599 - accuracy: 0.6727 - val_loss: 0.7233 - val_accuracy: 0.5906
# Epoch 56/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.5536 - accuracy: 0.6906 - val_loss: 0.7265 - val_accuracy: 0.5562
# Epoch 57/60
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5244 - accuracy: 0.7164 - val_loss: 0.7675 - val_accuracy: 0.6000
# Epoch 58/60
# 40/40 [==============================] - 3s 72ms/step - loss: 0.5357 - accuracy: 0.7047 - val_loss: 0.7012 - val_accuracy: 0.5938
# Epoch 59/60
# 40/40 [==============================] - 3s 75ms/step - loss: 0.4961 - accuracy: 0.7344 - val_loss: 0.7218 - val_accuracy: 0.6406
# Epoch 60/60
# 40/40 [==============================] - 4s 105ms/step - loss: 0.5072 - accuracy: 0.7297 - val_loss: 0.8423 - val_accuracy: 0.5562
# 10/10 [==============================] - 2s 29ms/step
# Fold score (Accuracy score): 0.55625
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  104        86
# Falso    |  56        74
# Fold #3
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 14s 151ms/step - loss: 0.6918 - accuracy: 0.5047 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 2/60
# 40/40 [==============================] - 3s 78ms/step - loss: 0.6954 - accuracy: 0.4992 - val_loss: 0.6936 - val_accuracy: 0.4969
# Epoch 3/60
# 40/40 [==============================] - 3s 75ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6940 - val_accuracy: 0.4969
# Epoch 4/60
60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6403 - accuracy: 0.6016 - val_loss: 0.6296 - val_accuracy: 0.5938
# Epoch 47/60
# 40/40 [==============================] - 4s 109ms/step - loss: 0.6013 - accuracy: 0.6406 - val_loss: 0.6352 - val_accuracy: 0.6031
# Epoch 48/60
# 40/40 [==============================] - 4s 105ms/step - loss: 0.6099 - accuracy: 0.6430 - val_loss: 0.6286 - val_accuracy: 0.6313
# Epoch 49/60
# 40/40 [==============================] - 5s 114ms/step - loss: 0.6033 - accuracy: 0.6406 - val_loss: 0.6340 - val_accuracy: 0.6313
# Epoch 50/60
# 40/40 [==============================] - 4s 109ms/step - loss: 0.5909 - accuracy: 0.6484 - val_loss: 0.6193 - val_accuracy: 0.6406
# Epoch 51/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5718 - accuracy: 0.6758 - val_loss: 0.6644 - val_accuracy: 0.6406
# Epoch 52/60
# 40/40 [==============================] - 3s 70ms/step - loss: 0.5779 - accuracy: 0.6578 - val_loss: 0.6055 - val_accuracy: 0.6406
# Epoch 53/60
# 40/40 [==============================] - 3s 81ms/step - loss: 0.5593 - accuracy: 0.6773 - val_loss: 0.6337 - val_accuracy: 0.6562
# Epoch 54/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5682 - accuracy: 0.6703 - val_loss: 0.6018 - val_accuracy: 0.6406
# Epoch 55/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5576 - accuracy: 0.6766 - val_loss: 0.6295 - val_accuracy: 0.6719
# Epoch 56/60
# 40/40 [==============================] - 4s 101ms/step - loss: 0.5441 - accuracy: 0.6703 - val_loss: 0.6133 - val_accuracy: 0.6375
# Epoch 57/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.5533 - accuracy: 0.6742 - val_loss: 0.6208 - val_accuracy: 0.6469
# Epoch 58/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.5311 - accuracy: 0.7063 - val_loss: 0.6074 - val_accuracy: 0.6562
# Epoch 59/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5163 - accuracy: 0.7023 - val_loss: 0.5912 - val_accuracy: 0.7000
# Epoch 60/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.5471 - accuracy: 0.6945 - val_loss: 0.6194 - val_accuracy: 0.6406
# 10/10 [==============================] - 2s 28ms/step
# Fold score (Accuracy score): 0.640625
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  101        57
# Falso    |  58        104
# Fold #4
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 11s 129ms/step - loss: 0.6961 - accuracy: 0.4805 - val_loss: 0.6920 - val_accuracy: 0.5063
# Epoch 2/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6940 - accuracy: 0.4969 - val_loss: 0.6951 - val_accuracy: 0.4938
# Epoch 3/60
# 40/40 [==============================] - 4s 88ms/step - loss: 0.6946 - accuracy: 0.4883 - val_loss: 0.6929 - val_accuracy: 0.5125
# Epoch 4/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.6942 - accuracy: 0.4906 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 5/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6926 - accuracy: 0.5141 - val_loss: 0.6918 - val_accuracy: 0.5375
# Epoch 6/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6920 - accuracy: 0.5219 - val_loss: 0.6908 - val_accuracy: 0.5469
# Epoch 7/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6967 - accuracy: 0.4906 - val_loss: 0.6919 - val_accuracy: 0.5344
# Epoch 8/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6926 - accuracy: 0.5039 - val_loss: 0.6914 - val_accuracy: 0.5250
# Epoch 9/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6928 - accuracy: 0.5148 - val_loss: 0.6947 - val_accuracy: 0.4969
# Epoch 10/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6928 - accuracy: 0.4992 - val_loss: 0.6906 - val_accuracy: 0.5344
# Epoch 11/60
# 40/40 [==============================] - 3s 81ms/step - loss: 0.6943 - accuracy: 0.4992 - val_loss: 0.6932 - val_accuracy: 0.4969
# Epoch 12/60
# 40/40 [==============================] - 3s 81ms/step - loss: 0.6930 - accuracy: 0.5023 - val_loss: 0.6900 - val_accuracy: 0.5344
# Epoch 13/60
# 40/40 [==============================] - 3s 75ms/step - loss: 0.6933 - accuracy: 0.5094 - val_loss: 0.6932 - val_accuracy: 0.5031
# Epoch 14/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6893 - val_accuracy: 0.5219
# Epoch 15/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6913 - accuracy: 0.5172 - val_loss: 0.6908 - val_accuracy: 0.5375
# Epoch 16/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6914 - accuracy: 0.5219 - val_loss: 0.6887 - val_accuracy: 0.5188
# Epoch 17/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6906 - accuracy: 0.5289 - val_loss: 0.6872 - val_accuracy: 0.4812
# Epoch 18/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6861 - accuracy: 0.5219 - val_loss: 0.6832 - val_accuracy: 0.5250
# Epoch 19/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6844 - accuracy: 0.5430 - val_loss: 0.6982 - val_accuracy: 0.4969
# Epoch 20/60
# 40/40 [==============================] - 3s 69ms/step - loss: 0.6814 - accuracy: 0.5578 - val_loss: 0.6861 - val_accuracy: 0.5531
# Epoch 21/60
# 40/40 [==============================] - 3s 76ms/step - loss: 0.6761 - accuracy: 0.5375 - val_loss: 0.6815 - val_accuracy: 0.5500
60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6189 - accuracy: 0.6320 - val_loss: 0.6445 - val_accuracy: 0.5969
# Epoch 43/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6056 - accuracy: 0.6344 - val_loss: 0.6346 - val_accuracy: 0.6125
# Epoch 44/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.5998 - accuracy: 0.6469 - val_loss: 0.6404 - val_accuracy: 0.6125
# Epoch 45/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6003 - accuracy: 0.6516 - val_loss: 0.6559 - val_accuracy: 0.6094
# Epoch 46/60
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5999 - accuracy: 0.6523 - val_loss: 0.6454 - val_accuracy: 0.6469
# Epoch 47/60
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5980 - accuracy: 0.6500 - val_loss: 0.6485 - val_accuracy: 0.6031
# Epoch 48/60
# 40/40 [==============================] - 3s 81ms/step - loss: 0.5721 - accuracy: 0.6695 - val_loss: 0.6776 - val_accuracy: 0.6125
# Epoch 49/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.5883 - accuracy: 0.6438 - val_loss: 0.6625 - val_accuracy: 0.6187
# Epoch 50/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5810 - accuracy: 0.6547 - val_loss: 0.6345 - val_accuracy: 0.6250
# Epoch 51/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.5604 - accuracy: 0.6859 - val_loss: 0.6519 - val_accuracy: 0.5906
# Epoch 52/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5549 - accuracy: 0.6789 - val_loss: 0.6346 - val_accuracy: 0.6438
# Epoch 53/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.5414 - accuracy: 0.6906 - val_loss: 0.6776 - val_accuracy: 0.6531
# Epoch 54/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5201 - accuracy: 0.7117 - val_loss: 0.6504 - val_accuracy: 0.6406
# Epoch 55/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.5502 - accuracy: 0.6812 - val_loss: 0.6337 - val_accuracy: 0.6656
# Epoch 56/60
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5294 - accuracy: 0.6820 - val_loss: 0.6302 - val_accuracy: 0.6156
# Epoch 57/60
# 40/40 [==============================] - 3s 78ms/step - loss: 0.5434 - accuracy: 0.7000 - val_loss: 0.6601 - val_accuracy: 0.6406
# Epoch 58/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5257 - accuracy: 0.7086 - val_loss: 0.6270 - val_accuracy: 0.6469
# Epoch 59/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5017 - accuracy: 0.7188 - val_loss: 0.6341 - val_accuracy: 0.6562
# Epoch 60/60
# 40/40 [==============================] - 3s 77ms/step - loss: 0.4942 - accuracy: 0.7141 - val_loss: 0.6480 - val_accuracy: 0.6687
# 10/10 [==============================] - 2s 29ms/step
# Fold score (Accuracy score): 0.66875
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  91        39
# Falso    |  67        123
# Fold #5
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 12s 133ms/step - loss: 0.6990 - accuracy: 0.4930 - val_loss: 0.6917 - val_accuracy: 0.5250
# Epoch 2/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6951 - accuracy: 0.4930 - val_loss: 0.6936 - val_accuracy: 0.4938
# Epoch 3/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6948 - accuracy: 0.5117 - val_loss: 0.6948 - val_accuracy: 0.4719
# Epoch 4/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6950 - accuracy: 0.4789 - val_loss: 0.6946 - val_accuracy: 0.4656
# Epoch 5/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6935 - accuracy: 0.4984 - val_loss: 0.6943 - val_accuracy: 0.4625
# Epoch 6/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6951 - accuracy: 0.4961 - val_loss: 0.6951 - val_accuracy: 0.4656
# Epoch 7/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6936 - accuracy: 0.5031 - val_loss: 0.6980 - val_accuracy: 0.4656
# Epoch 8/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.6938 - accuracy: 0.5086 - val_loss: 0.6929 - val_accuracy: 0.5156
# Epoch 9/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6923 - accuracy: 0.5211 - val_loss: 0.6955 - val_accuracy: 0.4750
# Epoch 10/60
# 40/40 [==============================] - 3s 86ms/step - loss: 0.6916 - accuracy: 0.5219 - val_loss: 0.7012 - val_accuracy: 0.4594
# Epoch 11/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.6928 - accuracy: 0.5156 - val_loss: 0.6909 - val_accuracy: 0.5219
# Epoch 12/60
# 40/40 [==============================] - 4s 103ms/step - loss: 0.6927 - accuracy: 0.5195 - val_loss: 0.6957 - val_accuracy: 0.4750
# Epoch 13/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6918 - accuracy: 0.5102 - val_loss: 0.6935 - val_accuracy: 0.5125
# Epoch 14/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6882 - accuracy: 0.5461 - val_loss: 0.7080 - val_accuracy: 0.4719
# Epoch 15/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6859 - accuracy: 0.5219 - val_loss: 0.6957 - val_accuracy: 0.4875
# Epoch 16/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6860 - accuracy: 0.5406 - val_loss: 0.6910 - val_accuracy: 0.5344
# Epoch 17/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6841 - accuracy: 0.5430 - val_loss: 0.7052 - val_accuracy: 0.4969
# Epoch 18/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6817 - accuracy: 0.5445 - val_loss: 0.7139 - val_accuracy: 0.4844
# Epoch 19/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6825 - accuracy: 0.5188 - val_loss: 0.6953 - val_accuracy: 0.5125
# Epoch 20/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6759 - accuracy: 0.5617 - val_loss: 0.6956 - val_accuracy: 0.5188
# Epoch 21/60
# 40/40 [==============================] - 4s 98ms/step - loss: 0.6721 - accuracy: 0.5742 - val_loss: 0.6900 - val_accuracy: 0.5406
# Epoch 22/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6824 - accuracy: 0.5383 - val_loss: 0.6996 - val_accuracy: 0.4906
# Epoch 23/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6734 - accuracy: 0.5633 - val_loss: 0.6920 - val_accuracy: 0.5125
# Epoch 24/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6699 - accuracy: 0.5625 - val_loss: 0.7130 - val_accuracy: 0.5188
# Epoch 25/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6631 - accuracy: 0.5805 - val_loss: 0.7076 - val_accuracy: 0.5063
# Epoch 26/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6618 - accuracy: 0.5719 - val_loss: 0.7088 - val_accuracy: 0.5094
# Epoch 27/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.6577 - accuracy: 0.5813 - val_loss: 0.6959 - val_accuracy: 0.5375
# Epoch 28/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.6590 - accuracy: 0.5789 - val_loss: 0.7042 - val_accuracy: 0.5094
# Epoch 29/60
# 40/40 [==============================] - 4s 100ms/step - loss: 0.6551 - accuracy: 0.5758 - val_loss: 0.6973 - val_accuracy: 0.5188
# Epoch 30/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6547 - accuracy: 0.5672 - val_loss: 0.6985 - val_accuracy: 0.5031
# Epoch 31/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6472 - accuracy: 0.5867 - val_loss: 0.6872 - val_accuracy: 0.5250
# Epoch 32/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6516 - accuracy: 0.5898 - val_loss: 0.6876 - val_accuracy: 0.5594
# Epoch 33/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6529 - accuracy: 0.5828 - val_loss: 0.7073 - val_accuracy: 0.5437
# Epoch 34/60
# 40/40 [==============================] - 5s 114ms/step - loss: 0.6313 - accuracy: 0.6031 - val_loss: 0.7189 - val_accuracy: 0.5219
# Epoch 35/60
# 40/40 [==============================] - 4s 103ms/step - loss: 0.6376 - accuracy: 0.6078 - val_loss: 0.7184 - val_accuracy: 0.5250
# Epoch 36/60
# 40/40 [==============================] - 5s 130ms/step - loss: 0.6293 - accuracy: 0.6234 - val_loss: 0.7426 - val_accuracy: 0.5312
# Epoch 37/60
# 40/40 [==============================] - 4s 107ms/step - loss: 0.6239 - accuracy: 0.6141 - val_loss: 0.7106 - val_accuracy: 0.5594
# Epoch 38/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6425 - accuracy: 0.5984 - val_loss: 0.6909 - val_accuracy: 0.5688
# Epoch 39/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.6257 - accuracy: 0.6086 - val_loss: 0.7099 - val_accuracy: 0.5375
# Epoch 40/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6136 - accuracy: 0.6164 - val_loss: 0.7043 - val_accuracy: 0.6031
# Epoch 41/60
# 40/40 [==============================] - 4s 98ms/step - loss: 0.6147 - accuracy: 0.6125 - val_loss: 0.7366 - val_accuracy: 0.5531
# Epoch 42/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6335 - accuracy: 0.5969 - val_loss: 0.6915 - val_accuracy: 0.5437
# Epoch 43/60
# 40/40 [==============================] - 3s 85ms/step - loss: 0.6117 - accuracy: 0.6344 - val_loss: 0.7169 - val_accuracy: 0.5656
# Epoch 44/60
# 40/40 [==============================] - 4s 107ms/step - loss: 0.5898 - accuracy: 0.6305 - val_loss: 0.7083 - val_accuracy: 0.5906
# Epoch 45/60
# 40/40 [==============================] - 4s 101ms/step - loss: 0.5862 - accuracy: 0.6586 - val_loss: 0.7297 - val_accuracy: 0.5750
# Epoch 46/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5797 - accuracy: 0.6609 - val_loss: 0.7239 - val_accuracy: 0.5750
# Epoch 47/60
# 40/40 [==============================] - 3s 81ms/step - loss: 0.5651 - accuracy: 0.6594 - val_loss: 0.7347 - val_accuracy: 0.5656
# Epoch 48/60
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5748 - accuracy: 0.6477 - val_loss: 0.7089 - val_accuracy: 0.5594
# Epoch 49/60
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5817 - accuracy: 0.6461 - val_loss: 0.7212 - val_accuracy: 0.5875
# Epoch 50/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.5585 - accuracy: 0.6766 - val_loss: 0.7300 - val_accuracy: 0.5875
# Epoch 51/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.5487 - accuracy: 0.6789 - val_loss: 0.7232 - val_accuracy: 0.5906
# Epoch 52/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5737 - accuracy: 0.6617 - val_loss: 0.7175 - val_accuracy: 0.6125
# Epoch 53/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.5511 - accuracy: 0.6664 - val_loss: 0.7202 - val_accuracy: 0.5844
# Epoch 54/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.5213 - accuracy: 0.6992 - val_loss: 0.7037 - val_accuracy: 0.6250
# Epoch 55/60
# 40/40 [==============================] - 3s 83ms/step - loss: 0.5423 - accuracy: 0.6938 - val_loss: 0.7630 - val_accuracy: 0.6062
# Epoch 56/60
# 40/40 [==============================] - 3s 82ms/step - loss: 0.5380 - accuracy: 0.6773 - val_loss: 0.7355 - val_accuracy: 0.5781
# Epoch 57/60
# 40/40 [==============================] - 3s 84ms/step - loss: 0.5305 - accuracy: 0.7016 - val_loss: 0.7171 - val_accuracy: 0.6062
# Epoch 58/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.5058 - accuracy: 0.7133 - val_loss: 0.7096 - val_accuracy: 0.5969
# Epoch 59/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.5203 - accuracy: 0.7039 - val_loss: 0.7278 - val_accuracy: 0.6000
# Epoch 60/60
# 40/40 [==============================] - 4s 88ms/step - loss: 0.4920 - accuracy: 0.7242 - val_loss: 0.7610 - val_accuracy: 0.5969
# 10/10 [==============================] - 2s 29ms/step
# Fold score (Accuracy score): 0.596875
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  75        55
# Falso    |  74        116
# -----------------------
# Cross-validated score (Accuracy score): 0.6125
# -----------------------
# Resumen
# Fold score (Accuracy score): 0.6
# Fold score (Accuracy score): 0.55625
# Fold score (Accuracy score): 0.640625
# Fold score (Accuracy score): 0.66875
# Fold score (Accuracy score): 0.596875

# %%
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")

y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
    
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# val_loss: 0.7011466026306152 val_accuracy: 0.637499988079071
# El algoritmo acerto 240 veces sobre los 320 casos.

# %%
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model

'''
Cross-validated score (Accuracy score): 0.8200663349917081
-----------------------
Resumen
Fold score (Accuracy score): 0.8281573498964804
Fold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687
Fold score (Accuracy score): 0.8008298755186722
Fold score (Accuracy score): 0.8174273858921162
Fold score (Accuracy score): 0.8112033195020747
'''
# Out:
# '\nCross-validated score (Accuracy score): 0.8200663349917081\n-----------------------\nResumen\nFold score (Accuracy score): 0.8281573498964804\nFold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687\nFold score (Accuracy score): 0.8008298755186722\nFold score (Accuracy score): 0.8174273858921162\nFold score (Accuracy score): 0.8112033195020747\n'

# %%
'''
val_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128
val_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128
val_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808
'''
# Out:
# '\nval_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128\nval_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128\nval_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808\n'

# %% [markdown]
# #### Crossvalidation

# %%
X = np.array(X)
y = np.array(y)
print(f"X:{X.shape} y:{y.shape}")
# Out:
# X:(2236, 40) y:(2236, 2)

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# El bloque realizara el k fold cross validation dividiendolo en 5 folds, se uso los MSE.

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_5.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
