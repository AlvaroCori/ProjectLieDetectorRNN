# %% [markdown]
# ## Nuevo modelo usando audios .wav, obteniendo su MFCC, aplicandolos a una RNN y validandolo con k fold cross validation

# %% [markdown]
# #### Nuevo modelo

# %% [markdown]
# #### Librerias

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display
import os
import soundfile as sf
import json
import random
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np

from keras import Sequential
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed

import datetime
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
random.seed(0)

# %% [markdown]
# #### Funciones a usar

# %%
#Obtiene el path con el nombre de todos los archivos de un directorio.
def get_files_from_path(directory):
    path_files = []
    dir_list = os.listdir(directory)
    for path in dir_list:
        path_files.append(directory+"\\"+path)
    return path_files


#Extrae los paths que cumplan con un codigo
def extract_paths_for_emotions_keys(emotions_code, files_path, get_code):
    paths = []
    emotions_set = set(emotions_code)
    for code_file in files_path:
        if (get_code(code_file) in emotions_set):
            paths.append(code_file)
    return paths


#Obtiene el codigo en el nombre del archivo para el dataset CREMA-D
def get_code_esp(path):
    return path[114]#path[110] prueba

def scaled_datas(X):
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled

#Esta función abre el archivo .wav y obtiene el mfcc escalado en un vector de 40 elementos.
def features_extractor(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except:
        print("rrrr-", file_name)


#Esta función permite guardar los MFCC en 'features', el código en 'code' y su dirección en 'path' en un archivo json. 
def save_elements_in_json(examples_saved, name):
    json_files = []
    json_file = {}
    index = 0
    for file in examples_saved:
        json_file = {"id": index, "features":[str(elem) for elem in file[0]] ,"code":file[1], "path":file[2]}
        json_files.append(json_file)
        index += 1
    json_object = json.dumps(json_files)
    with open(f"{name}.json", "w") as outfile:
        outfile.write(json_object)
   

#La función permite cargar datos del MFCC y código desde un archivo json.
def load_elements_from_json(name):
    f = open(f'{name}.json')
    data = json.load(f)
    examples = []
    for element in data:
        examples.append(([float(feature) for feature in (element["features"])], element["code"]))
    return examples


#La función nos permite devolver una lista de MFCC obtenidos de una lista de paths. 
#El MFCC tiene un límite que no le permite cargar archivos menor o igual a 44 kb.
#Con el diccionario obtenemos el total de audios recuperados por emoción.
def get_features(paths,get_code, files_filters = dict()):
    examples = []
    for path in paths:
        code = get_code(path)
        file_stats = os.stat(path)
        feature = features_extractor(path)
        files_filters[code]+= 1
        examples.append((feature,code))
    print(f"Se obtuvo el MFCC de unos {len(paths)} sobre {sum(files_filters[files] for files in files_filters)} audios.")
    return examples


#Selecciona n ejemplos que necesitemos y los mezcla.
def select_elements(examples, code, quantity, new_code):
    random.shuffle(examples)
    elements = []
    counter = 1
    for example in examples:
        if (counter > quantity):
            break
        if code == example[1]:
            elements.append((example[0],new_code))
            counter = counter + 1
    return elements

# %% [markdown]
# Los siguientes bloques obtienen los paths y filtra las emociones que necesitemos en cada dataset (CREMA-D y SAVEE).

# %% [markdown]
# #### Funciones para obtener los datos

# %%
#Obtiene todos los datos de CREMA-D y SAVEE para un  
def get_datas():
    files_path = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\data")
    emotions_code = ["t", "f"]
    datas_files = extract_paths_for_emotions_keys(emotions_code, files_path, get_code_esp)
    examples = []
    files_filters = dict()
    files_filters["t"] = 0
    files_filters["f"] = 0
    examples = get_features(datas_files, get_code_esp, files_filters)
    return examples

#Obtiene los datos de entrada para la red neuronal x: mfcc normalizados, y: labeles categorizados
def get_entries():
    all_examples = get_datas()
    entries = []
    for example in all_examples:
        entries.append((example[0], example[1]))
    datas = select_elements(entries, 't', 800,"without_stress")
    datas += select_elements(entries, 'f', 800, "stress")
    random.shuffle(datas)
    X = []
    y = []
    for data in datas:
        X.append(data[0])
        y.append(data[1])
    labelencoder=preprocessing.LabelEncoder()
    y = to_categorical(labelencoder.fit_transform(y))
    return X, y

#Obtiene los datos divididos de entrenamiento y tests
def obtain_datas_train_and_test(percentage):
    X, y = get_entries()
    
    X_test, X_train, y_test, y_train = train_test_split(X, y, test_size =percentage,random_state=0)
    y = np.array(y)
    X_train = np.array(X_train)
    X_test = np.array(X_test)
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = obtain_datas_train_and_test(0.8)
num_labels = y_train.shape[1] + y_test.shape[1]
dim_entrada = (X_train.shape[1],1)
# Out:
# Se obtuvo el MFCC de unos 1600 sobre 1600 audios.

# %%
X_train[0]
# Out:
# array([-2.03619125e+02,  1.32924957e+02,  1.16074324e+01,  4.22039948e+01,
#         1.59348106e+01,  1.00078325e+01,  3.09595966e+00,  9.74628162e+00,
#        -6.43884420e+00,  5.50276041e+00, -3.89752269e+00,  3.09939122e+00,
#         1.09478855e+00,  3.97362924e+00,  1.78057158e+00,  6.92045116e+00,
#         9.58635986e-01,  1.92379892e+00,  1.48452592e+00, -2.62816620e+00,
#        -3.95873570e+00,  1.12830214e-01, -7.04381943e+00, -3.05793919e-02,
#        -4.39929628e+00,  6.19296312e-01, -3.25743532e+00, -2.55520612e-01,
#        -6.84725106e-01, -8.80580246e-01,  2.59195876e+00, -2.84970117e+00,
#        -1.94983974e-01, -3.07813001e+00, -1.43103153e-01, -1.69904196e+00,
#        -7.15058565e-01, -6.39670566e-02, -1.59365737e+00, -6.24961972e-01],
#       dtype=float32)

# %%
#probando nueva arquitectura
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=True))
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Activation('relu'))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model

# %%
model = new_RNN()
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 40, 50)            10400
#
#  lstm_15 (LSTM)              (None, 50)                20200
#
#  activation_36 (Activation)  (None, 50)                0
#
#  activation_37 (Activation)  (None, 50)                0
#
#  activation_38 (Activation)  (None, 50)                0
#
#  dropout_12 (Dropout)        (None, 50)                0
#
#  dense_12 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 30,702
# Trainable params: 30,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
k_fold = KFold(5)
fold = 0
y_tests = []
predictions = []
scores = []
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))
for train, test in k_fold.split(X):
    fold = fold + 1
    print(f"Fold #{fold}")
    X_train = X[train]
    X_test = X[test]
    y_train = y[train]
    y_test = y[test]
    print(f"Train - X:{X_train.shape} y:{y_train.shape}")
    print(f"Test - X:{X_test.shape} y:{y_test.shape}")
    
    num_labels = y.shape[1]
    dim_entrada = (X_train.shape[1],1)

    #model = new_RNN()
    model = new_RNN()
    callbacks = []
    '''
    callbacks = [
    EarlyStopping(
            monitor="val_loss",
            min_delta=1e-2,
            patience=20,
            verbose=1,
        )
    ]
    '''
    num_epochs = 58
    num_batch_size = 32
    start = datetime.datetime.now()
   
    results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)

    pred = model.predict(X_test)
    y_tests.append(y_test)
    pred=[([1,0] if i[0]>i[1] else [0,1]) for i in pred]
    predictions.append(pred)
    score = metrics.accuracy_score(pred, y_test)
    math = confusion_matrix([(1 if x[0]==1 else 0) for x in pred],[(1 if x[0]==1 else 0) for x in y_test], labels=[1,0])
    scores.append([score])
    print(f"Fold score (Accuracy score): {score}")
    print("Matriz de confusion")
    print("-------------------")
    print("---------| Verdadero | Falso |")
    print(f"Verdadero|  {math[0][0]}        {math[0][1]}")
    print(f"Falso    |  {math[1][0]}        {math[1][1]}")

y_tests = np.concatenate(y_tests)
predictions = np.concatenate(predictions)
score = metrics.accuracy_score(predictions, y_tests)
print("-----------------------")
print(f"Cross-validated score (Accuracy score): {score}")
print("-----------------------")
print("Resumen")
for result in scores:
    print(f"Fold score (Accuracy score): {result[0]}")
# Out:
# Fold #1
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/58
# 40/40 [==============================] - 7s 83ms/step - loss: 0.6966 - accuracy: 0.5008 - val_loss: 0.7019 - val_accuracy: 0.4344
# Epoch 2/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6962 - accuracy: 0.4930 - val_loss: 0.7014 - val_accuracy: 0.4344
# Epoch 3/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.6958 - accuracy: 0.5102 - val_loss: 0.6997 - val_accuracy: 0.4375
# Epoch 4/58
# 40/40 [==============================] - 2s 53ms/step - loss: 0.6912 - accuracy: 0.5273 - val_loss: 0.6990 - val_accuracy: 0.4437
# Epoch 5/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6932 - accuracy: 0.5195 - val_loss: 0.6990 - val_accuracy: 0.4344
# Epoch 6/58
# 40/40 [==============================] - 2s 58ms/step - loss: 0.6951 - accuracy: 0.5234 - val_loss: 0.7008 - val_accuracy: 0.4406
# Epoch 7/58
# 40/40 [==============================] - 3s 69ms/step - loss: 0.6925 - accuracy: 0.5133 - val_loss: 0.6989 - val_accuracy: 0.4437
# Epoch 8/58
# Epoch 47/58
# 40/40 [==============================] - 2s 58ms/step - loss: 0.6342 - accuracy: 0.6203 - val_loss: 0.6629 - val_accuracy: 0.5875
# Epoch 48/58
# 40/40 [==============================] - 3s 69ms/step - loss: 0.6082 - accuracy: 0.6633 - val_loss: 0.6546 - val_accuracy: 0.6000
# Epoch 49/58
# 40/40 [==============================] - 3s 69ms/step - loss: 0.6179 - accuracy: 0.6398 - val_loss: 0.6750 - val_accuracy: 0.5875
# Epoch 50/58
# 40/40 [==============================] - 3s 64ms/step - loss: 0.6074 - accuracy: 0.6625 - val_loss: 0.6749 - val_accuracy: 0.5781
# Epoch 51/58
# 40/40 [==============================] - 2s 61ms/step - loss: 0.6049 - accuracy: 0.6586 - val_loss: 0.6567 - val_accuracy: 0.5875
# Epoch 52/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.5940 - accuracy: 0.6664 - val_loss: 0.6545 - val_accuracy: 0.5813
# Epoch 53/58
# 40/40 [==============================] - 3s 72ms/step - loss: 0.5921 - accuracy: 0.6609 - val_loss: 0.6835 - val_accuracy: 0.5719
# Epoch 54/58
# 40/40 [==============================] - 3s 77ms/step - loss: 0.5975 - accuracy: 0.6641 - val_loss: 0.6376 - val_accuracy: 0.6125
# Epoch 55/58
# 40/40 [==============================] - 2s 56ms/step - loss: 0.5831 - accuracy: 0.6930 - val_loss: 0.6450 - val_accuracy: 0.5750
# Epoch 56/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.5764 - accuracy: 0.6859 - val_loss: 0.6374 - val_accuracy: 0.6281
# Epoch 57/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5545 - accuracy: 0.6969 - val_loss: 0.6505 - val_accuracy: 0.6000
# Epoch 58/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5568 - accuracy: 0.6906 - val_loss: 0.6669 - val_accuracy: 0.5906
# 10/10 [==============================] - 1s 24ms/step
# Fold score (Accuracy score): 0.590625
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  120        77
# Falso    |  54        69
# Fold #2
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/58
# 40/40 [==============================] - 27s 585ms/step - loss: 0.7020 - accuracy: 0.5102 - val_loss: 0.6953 - val_accuracy: 0.5188
# Epoch 2/58
# 40/40 [==============================] - 2s 43ms/step - loss: 0.6969 - accuracy: 0.5016 - val_loss: 0.6931 - val_accuracy: 0.5156
# Epoch 3/58
# 40/40 [==============================] - 2s 45ms/step - loss: 0.6969 - accuracy: 0.5133 - val_loss: 0.6931 - val_accuracy: 0.5125
# Epoch 4/58
# 40/40 [==============================] - 2s 43ms/step - loss: 0.6944 - accuracy: 0.5031 - val_loss: 0.6928 - val_accuracy: 0.5156
# Epoch 5/58
# 40/40 [==============================] - 2s 47ms/step - loss: 0.6922 - accuracy: 0.5164 - val_loss: 0.6925 - val_accuracy: 0.5063
# Epoch 6/58
# 40/40 [==============================] - 2s 45ms/step - loss: 0.6957 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5000
# 40/40 [==============================] - 3s 71ms/step - loss: 0.6394 - accuracy: 0.6250 - val_loss: 0.6510 - val_accuracy: 0.5688
# Epoch 45/58
# 40/40 [==============================] - 3s 68ms/step - loss: 0.6228 - accuracy: 0.6219 - val_loss: 0.6316 - val_accuracy: 0.6000
# Epoch 46/58
# 40/40 [==============================] - 3s 83ms/step - loss: 0.6162 - accuracy: 0.6266 - val_loss: 0.6542 - val_accuracy: 0.5906
# Epoch 47/58
# 40/40 [==============================] - 3s 72ms/step - loss: 0.6156 - accuracy: 0.6359 - val_loss: 0.6358 - val_accuracy: 0.6000
# Epoch 48/58
# 40/40 [==============================] - 3s 74ms/step - loss: 0.6149 - accuracy: 0.6289 - val_loss: 0.6434 - val_accuracy: 0.5875
# Epoch 49/58
# 40/40 [==============================] - 3s 75ms/step - loss: 0.6175 - accuracy: 0.6352 - val_loss: 0.6476 - val_accuracy: 0.5875
# Epoch 50/58
# 40/40 [==============================] - 3s 71ms/step - loss: 0.5897 - accuracy: 0.6727 - val_loss: 0.6439 - val_accuracy: 0.5938
# Epoch 51/58
# 40/40 [==============================] - 2s 60ms/step - loss: 0.5861 - accuracy: 0.6508 - val_loss: 0.6096 - val_accuracy: 0.6344
# Epoch 52/58
# 40/40 [==============================] - 2s 61ms/step - loss: 0.5780 - accuracy: 0.6562 - val_loss: 0.6238 - val_accuracy: 0.6187
# Epoch 53/58
# 40/40 [==============================] - 3s 70ms/step - loss: 0.5773 - accuracy: 0.6570 - val_loss: 0.6141 - val_accuracy: 0.6313
# Epoch 54/58
# 40/40 [==============================] - 3s 75ms/step - loss: 0.5808 - accuracy: 0.6547 - val_loss: 0.6127 - val_accuracy: 0.6562
# Epoch 55/58
# 40/40 [==============================] - 3s 66ms/step - loss: 0.5563 - accuracy: 0.6773 - val_loss: 0.6443 - val_accuracy: 0.6438
# Epoch 56/58
# 40/40 [==============================] - 2s 60ms/step - loss: 0.5452 - accuracy: 0.6898 - val_loss: 0.6176 - val_accuracy: 0.6500
# Epoch 57/58
# 40/40 [==============================] - 2s 60ms/step - loss: 0.5489 - accuracy: 0.6797 - val_loss: 0.6219 - val_accuracy: 0.6094
# Epoch 58/58
# 40/40 [==============================] - 2s 60ms/step - loss: 0.5468 - accuracy: 0.7016 - val_loss: 0.5988 - val_accuracy: 0.6531
# 10/10 [==============================] - 1s 16ms/step
# Fold score (Accuracy score): 0.653125
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  105        57
# Falso    |  54        104
# Fold #4
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/58
# 40/40 [==============================] - 7s 96ms/step - loss: 0.6979 - accuracy: 0.5016 - val_loss: 0.6909 - val_accuracy: 0.5312
# Epoch 2/58
# 40/40 [==============================] - 3s 75ms/step - loss: 0.6966 - accuracy: 0.4969 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 3/58
# 40/40 [==============================] - 3s 74ms/step - loss: 0.6956 - accuracy: 0.5031 - val_loss: 0.6945 - val_accuracy: 0.4500
# Epoch 4/58
# Epoch 43/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.6051 - accuracy: 0.6594 - val_loss: 0.6694 - val_accuracy: 0.5594
# Epoch 44/58
# 40/40 [==============================] - 2s 49ms/step - loss: 0.6100 - accuracy: 0.6711 - val_loss: 0.6799 - val_accuracy: 0.5656
# Epoch 45/58
# 40/40 [==============================] - 2s 53ms/step - loss: 0.5926 - accuracy: 0.6508 - val_loss: 0.6895 - val_accuracy: 0.5688
# Epoch 46/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.5860 - accuracy: 0.6680 - val_loss: 0.6449 - val_accuracy: 0.6031
# Epoch 47/58
# 40/40 [==============================] - 3s 65ms/step - loss: 0.5707 - accuracy: 0.6664 - val_loss: 0.6615 - val_accuracy: 0.5781
# Epoch 48/58
# 40/40 [==============================] - 3s 66ms/step - loss: 0.5954 - accuracy: 0.6633 - val_loss: 0.6719 - val_accuracy: 0.5562
# Epoch 49/58
# 40/40 [==============================] - 3s 72ms/step - loss: 0.5761 - accuracy: 0.6711 - val_loss: 0.6930 - val_accuracy: 0.5813
# Epoch 50/58
# 40/40 [==============================] - 3s 65ms/step - loss: 0.5744 - accuracy: 0.6758 - val_loss: 0.6411 - val_accuracy: 0.6125
# Epoch 51/58
# 40/40 [==============================] - 2s 61ms/step - loss: 0.5693 - accuracy: 0.6891 - val_loss: 0.6292 - val_accuracy: 0.6344
# Epoch 52/58
# 40/40 [==============================] - 2s 61ms/step - loss: 0.5497 - accuracy: 0.7070 - val_loss: 0.6219 - val_accuracy: 0.6687
# Epoch 53/58
# 40/40 [==============================] - 2s 60ms/step - loss: 0.5630 - accuracy: 0.6859 - val_loss: 0.6370 - val_accuracy: 0.6281
# Epoch 54/58
# 40/40 [==============================] - 3s 74ms/step - loss: 0.5846 - accuracy: 0.6664 - val_loss: 0.6449 - val_accuracy: 0.6313
# Epoch 55/58
# 40/40 [==============================] - 3s 87ms/step - loss: 0.5556 - accuracy: 0.6914 - val_loss: 0.6087 - val_accuracy: 0.6438
# Epoch 56/58
# 40/40 [==============================] - 3s 76ms/step - loss: 0.5362 - accuracy: 0.6961 - val_loss: 0.6954 - val_accuracy: 0.6062
# Epoch 57/58
# 40/40 [==============================] - 3s 68ms/step - loss: 0.5480 - accuracy: 0.6906 - val_loss: 0.6644 - val_accuracy: 0.6438
# Epoch 58/58
# 40/40 [==============================] - 2s 55ms/step - loss: 0.5322 - accuracy: 0.7008 - val_loss: 0.6123 - val_accuracy: 0.6719
# 10/10 [==============================] - 2s 16ms/step
# Fold score (Accuracy score): 0.671875
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  97        44
# Falso    |  61        118
# Fold #5
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/58
# 40/40 [==============================] - 6s 70ms/step - loss: 0.7006 - accuracy: 0.4773 - val_loss: 0.7006 - val_accuracy: 0.4656
# Epoch 2/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.6950 - accuracy: 0.4906 - val_loss: 0.6941 - val_accuracy: 0.4938
# 40/40 [==============================] - 3s 65ms/step - loss: 0.6372 - accuracy: 0.6141 - val_loss: 0.7041 - val_accuracy: 0.5813
# Epoch 42/58
# 40/40 [==============================] - 2s 58ms/step - loss: 0.6367 - accuracy: 0.6328 - val_loss: 0.6859 - val_accuracy: 0.5719
# Epoch 43/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6270 - accuracy: 0.6383 - val_loss: 0.6852 - val_accuracy: 0.5844
# Epoch 44/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6172 - accuracy: 0.6172 - val_loss: 0.7118 - val_accuracy: 0.5094
# Epoch 45/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.6270 - accuracy: 0.6234 - val_loss: 0.7017 - val_accuracy: 0.5531
# Epoch 46/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.6076 - accuracy: 0.6578 - val_loss: 0.7402 - val_accuracy: 0.5188
# Epoch 47/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.6112 - accuracy: 0.6422 - val_loss: 0.7203 - val_accuracy: 0.6125
# Epoch 48/58
# 40/40 [==============================] - 2s 57ms/step - loss: 0.6048 - accuracy: 0.6445 - val_loss: 0.7250 - val_accuracy: 0.6094
# Epoch 49/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.5912 - accuracy: 0.6734 - val_loss: 0.6829 - val_accuracy: 0.6031
# Epoch 50/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5819 - accuracy: 0.6727 - val_loss: 0.6984 - val_accuracy: 0.6281
# Epoch 51/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5964 - accuracy: 0.6633 - val_loss: 0.6935 - val_accuracy: 0.5938
# Epoch 52/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.5864 - accuracy: 0.6680 - val_loss: 0.6767 - val_accuracy: 0.6125
# Epoch 53/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5633 - accuracy: 0.6891 - val_loss: 0.6758 - val_accuracy: 0.6281
# Epoch 54/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.5685 - accuracy: 0.6773 - val_loss: 0.6807 - val_accuracy: 0.6031
# Epoch 55/58
# 40/40 [==============================] - 2s 57ms/step - loss: 0.5540 - accuracy: 0.6969 - val_loss: 0.6666 - val_accuracy: 0.6250
# Epoch 56/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5510 - accuracy: 0.6906 - val_loss: 0.6714 - val_accuracy: 0.6187
# Epoch 57/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5304 - accuracy: 0.7219 - val_loss: 0.6543 - val_accuracy: 0.6187
# Epoch 58/58
# 40/40 [==============================] - 2s 53ms/step - loss: 0.5294 - accuracy: 0.7180 - val_loss: 0.6501 - val_accuracy: 0.6500
# 10/10 [==============================] - 1s 18ms/step
# Fold score (Accuracy score): 0.65
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  86        49
# Falso    |  63        122
# -----------------------
# Cross-validated score (Accuracy score): 0.628125
# -----------------------
# Resumen
# Fold score (Accuracy score): 0.590625
# Fold score (Accuracy score): 0.575
# Fold score (Accuracy score): 0.653125
# Fold score (Accuracy score): 0.671875
# Fold score (Accuracy score): 0.65

# %%
#50 0.77
model = new_RNN()
model.summary()
callbacks = []
'''
callbacks = [
    EarlyStopping(
        monitor="val_accuracy",
        min_delta=0.01, #si un epochs mejora como un min_delta respecto a la anterior, no contara como mejora
        patience=70,#numero de epochs sin mejoras que se tendra paciencia
        verbose=1,#mostrar informacion extra, 0 no mostrar
     )
]
'''
num_epochs = 58
num_batch_size = 32
start = datetime.datetime.now()
   
results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)
duration = datetime.datetime.now() - start
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 40, 50)            10400
#
#  lstm_29 (LSTM)              (None, 50)                20200
#
#  activation_57 (Activation)  (None, 50)                0
#
#  activation_58 (Activation)  (None, 50)                0
#
#  activation_59 (Activation)  (None, 50)                0
#
#  dropout_19 (Dropout)        (None, 50)                0
#
#  dense_19 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 30,702
# Trainable params: 30,702
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/58
# 40/40 [==============================] - 7s 102ms/step - loss: 0.6985 - accuracy: 0.5242 - val_loss: 0.6882 - val_accuracy: 0.5250
# Epoch 2/58
# 40/40 [==============================] - 2s 49ms/step - loss: 0.6932 - accuracy: 0.5180 - val_loss: 0.6951 - val_accuracy: 0.4844
# Epoch 3/58
# 40/40 [==============================] - 2s 50ms/step - loss: 0.6931 - accuracy: 0.5242 - val_loss: 0.6932 - val_accuracy: 0.5188
# Epoch 4/58
# 40/40 [==============================] - 3s 67ms/step - loss: 0.6940 - accuracy: 0.5094 - val_loss: 0.6952 - val_accuracy: 0.4594
# Epoch 5/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6938 - accuracy: 0.5047 - val_loss: 0.6994 - val_accuracy: 0.4625
# Epoch 6/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6908 - accuracy: 0.5234 - val_loss: 0.6969 - val_accuracy: 0.4625
# Epoch 7/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.6893 - accuracy: 0.5344 - val_loss: 0.6954 - val_accuracy: 0.5125
# Epoch 8/58
# 40/40 [==============================] - 2s 56ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6929 - val_accuracy: 0.5250
# Epoch 9/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.6914 - accuracy: 0.5320 - val_loss: 0.6972 - val_accuracy: 0.4844
# Epoch 10/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5957 - accuracy: 0.6242 - val_loss: 0.7002 - val_accuracy: 0.5469
# Epoch 50/58
# 40/40 [==============================] - 2s 50ms/step - loss: 0.5796 - accuracy: 0.6508 - val_loss: 0.6907 - val_accuracy: 0.5938
# Epoch 51/58
# 40/40 [==============================] - 2s 54ms/step - loss: 0.5779 - accuracy: 0.6594 - val_loss: 0.6891 - val_accuracy: 0.5437
# Epoch 52/58
# 40/40 [==============================] - 2s 57ms/step - loss: 0.5626 - accuracy: 0.6516 - val_loss: 0.6772 - val_accuracy: 0.5781
# Epoch 53/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5499 - accuracy: 0.6570 - val_loss: 0.6688 - val_accuracy: 0.5750
# Epoch 54/58
# 40/40 [==============================] - 2s 50ms/step - loss: 0.5507 - accuracy: 0.6562 - val_loss: 0.6888 - val_accuracy: 0.5969
# Epoch 55/58
# 40/40 [==============================] - 2s 52ms/step - loss: 0.5434 - accuracy: 0.6617 - val_loss: 0.6776 - val_accuracy: 0.5938
# Epoch 56/58
# 40/40 [==============================] - 2s 51ms/step - loss: 0.5366 - accuracy: 0.6781 - val_loss: 0.6731 - val_accuracy: 0.5875
# Epoch 57/58
# 40/40 [==============================] - 2s 50ms/step - loss: 0.5564 - accuracy: 0.6641 - val_loss: 0.6944 - val_accuracy: 0.5781
# Epoch 58/58
# 40/40 [==============================] - 3s 64ms/step - loss: 0.5335 - accuracy: 0.7016 - val_loss: 0.6501 - val_accuracy: 0.6031
# val_loss: 0.6500877737998962 val_accuracy: 0.6031249761581421
# 10/10 [==============================] - 2s 19ms/step
# El algoritmo acerto 193 veces sobre los 320 casos.

# %%
training_loss = results.history['loss']
test_loss = results.history['val_loss']
epochs_range = range(1, len(training_loss) + 1)

# %%
plt.plot(epochs_range, training_loss, 'r',marker="o",linestyle="--")
plt.plot(epochs_range, test_loss, 'b',marker="o",linestyle="-")
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.rcParams["figure.figsize"] = (20,8)
plt.show()

# %%
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")

y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
    
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# val_loss: 0.7190426588058472 val_accuracy: 0.71875
# El algoritmo acerto 230 veces sobre los 320 casos.

# %%
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
# Out:
# '\nCross-validated score (Accuracy score): 0.8200663349917081\n-----------------------\nResumen\nFold score (Accuracy score): 0.8281573498964804\nFold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687\nFold score (Accuracy score): 0.8008298755186722\nFold score (Accuracy score): 0.8174273858921162\nFold score (Accuracy score): 0.8112033195020747\n'
