# %% [markdown]
# ## Antiguo proyecto de Redes Neuronales Recurrentes usando audios .wav, obteniendo su MFCC, aplicandolos a una RNN y validandolo con k fold cross validation

# %% [markdown]
# #### Librerias

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display
import os
import soundfile as sf
import json
import random
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np

from keras import Sequential
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed

import datetime
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
random.seed(0)

# %% [markdown]
# #### Funciones a usar

# %%
#Obtiene el path con el nombre de todos los archivos de un directorio.
def get_files_from_path(directory):
    path_files = []
    dir_list = os.listdir(directory)
    for path in dir_list:
        path_files.append(directory+"\\"+path)
    return path_files


#Extrae los paths que cumplan con un codigo
def extract_paths_for_emotions_keys(emotions_code, files_path, get_code):
    paths = []
    emotions_set = set(emotions_code)
    for code_file in files_path:
        if (get_code(code_file) in emotions_set):
            paths.append(code_file)
    return paths


#Obtiene el codigo en el nombre del archivo para el dataset CREMA-D
def get_code_esp(path):
    return path[114]#path[110] prueba

def scaled_datas(X):
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled

#Esta función abre el archivo .wav y obtiene el mfcc escalado en un vector de 40 elementos.
def features_extractor(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except:
        print("rrrr-", file_name)


#Esta función permite guardar los MFCC en 'features', el código en 'code' y su dirección en 'path' en un archivo json. 
def save_elements_in_json(examples_saved, name):
    json_files = []
    json_file = {}
    index = 0
    for file in examples_saved:
        json_file = {"id": index, "features":[str(elem) for elem in file[0]] ,"code":file[1], "path":file[2]}
        json_files.append(json_file)
        index += 1
    json_object = json.dumps(json_files)
    with open(f"{name}.json", "w") as outfile:
        outfile.write(json_object)
   

#La función permite cargar datos del MFCC y código desde un archivo json.
def load_elements_from_json(name):
    f = open(f'{name}.json')
    data = json.load(f)
    examples = []
    for element in data:
        examples.append(([float(feature) for feature in (element["features"])], element["code"]))
    return examples


#La función nos permite devolver una lista de MFCC obtenidos de una lista de paths. 
#El MFCC tiene un límite que no le permite cargar archivos menor o igual a 44 kb.
#Con el diccionario obtenemos el total de audios recuperados por emoción.
def get_features(paths,get_code, files_filters = dict()):
    examples = []
    for path in paths:
        code = get_code(path)
        file_stats = os.stat(path)
        feature = features_extractor(path)
        files_filters[code]+= 1
        examples.append((feature,code))
    print(f"Se obtuvo el MFCC de unos {len(paths)} sobre {sum(files_filters[files] for files in files_filters)} audios.")
    return examples


#Selecciona n ejemplos que necesitemos y los mezcla.
def select_elements(examples, code, quantity, new_code):
    random.shuffle(examples)
    elements = []
    counter = 1
    for example in examples:
        if (counter > quantity):
            break
        if code == example[1]:
            elements.append((example[0],new_code))
            counter = counter + 1
    return elements

# %% [markdown]
# Los siguientes bloques obtienen los paths y filtra las emociones que necesitemos en cada dataset (CREMA-D y SAVEE).

# %% [markdown]
# #### Funciones para obtener los datos

# %%
#Obtiene todos los datos de CREMA-D y SAVEE para un  
def get_datas():
    files_path = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\data")
    emotions_code = ["t", "f"]
    datas_files = extract_paths_for_emotions_keys(emotions_code, files_path, get_code_esp)
    examples = []
    files_filters = dict()
    files_filters["t"] = 0
    files_filters["f"] = 0
    examples = get_features(datas_files, get_code_esp, files_filters)
    return examples

#Obtiene los datos de entrada para la red neuronal x: mfcc normalizados, y: labeles categorizados
def get_entries():
    all_examples = get_datas()
    entries = []
    for example in all_examples:
        entries.append((example[0], example[1]))
    datas = select_elements(entries, 't', 800,"without_stress")
    datas += select_elements(entries, 'f', 800, "stress")
    random.shuffle(datas)
    X = []
    y = []
    for data in datas:
        X.append(data[0])
        y.append(data[1])
    labelencoder=preprocessing.LabelEncoder()
    y = to_categorical(labelencoder.fit_transform(y))
    return X, y

#Obtiene los datos divididos de entrenamiento y tests
def obtain_datas_train_and_test(percentage):
    X, y = get_entries()
    
    X_test, X_train, y_test, y_train = train_test_split(X, y, test_size =percentage,random_state=0)
    y = np.array(y)
    X_train = np.array(X_train)
    X_test = np.array(X_test)
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = obtain_datas_train_and_test(0.8)
num_labels = y_train.shape[1] + y_test.shape[1]
dim_entrada = (X_train.shape[1],1)
# Out:
# Se obtuvo el MFCC de unos 1600 sobre 1600 audios.

# %%
X_train[0]
# Out:
# array([-2.03619125e+02,  1.32924957e+02,  1.16074324e+01,  4.22039948e+01,
#         1.59348106e+01,  1.00078325e+01,  3.09595966e+00,  9.74628162e+00,
#        -6.43884420e+00,  5.50276041e+00, -3.89752269e+00,  3.09939122e+00,
#         1.09478855e+00,  3.97362924e+00,  1.78057158e+00,  6.92045116e+00,
#         9.58635986e-01,  1.92379892e+00,  1.48452592e+00, -2.62816620e+00,
#        -3.95873570e+00,  1.12830214e-01, -7.04381943e+00, -3.05793919e-02,
#        -4.39929628e+00,  6.19296312e-01, -3.25743532e+00, -2.55520612e-01,
#        -6.84725106e-01, -8.80580246e-01,  2.59195876e+00, -2.84970117e+00,
#        -1.94983974e-01, -3.07813001e+00, -1.43103153e-01, -1.69904196e+00,
#        -7.15058565e-01, -6.39670566e-02, -1.59365737e+00, -6.24961972e-01],
#       dtype=float32)

# %%
'''
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50, input_shape = dim_entrada))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model
    
    tang_hiperbolica
'''
#redes neuronales recurrentes
#Datos son audios convertidos a MFCC 
#mayor accuracy o (porcentaje de aciertos) 


#probando nueva arquitectura
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=True))
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=True))
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

    return model

# %%
model = new_RNN()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 40, 50)            10400
#
#  lstm_1 (LSTM)               (None, 40, 50)            20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  activation (Activation)     (None, 50)                0
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 50,902
# Trainable params: 50,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
#50 0.77
model = new_RNN()
model.summary()
#https://keras.io/api/callbacks/early_stopping/
callbacks = []
'''
callbacks = [
    EarlyStopping(
        monitor="val_accuracy",
        min_delta=0.01, #si un epochs mejora como un min_delta respecto a la anterior, no contara como mejora
        patience=70,#numero de epochs sin mejoras que se tendra paciencia
        verbose=1,#mostrar informacion extra, 0 no mostrar
     )
]
'''
num_epochs = 100
num_batch_size = 32
start = datetime.datetime.now()
   
results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)
duration = datetime.datetime.now() - start
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 40, 50)            10400
#
#  lstm_4 (LSTM)               (None, 40, 50)            20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  activation_1 (Activation)   (None, 50)                0
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 50,902
# Trainable params: 50,902
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 40/40 [==============================] - 13s 160ms/step - loss: 0.6964 - accuracy: 0.5117 - val_loss: 0.6919 - val_accuracy: 0.5219
# Epoch 2/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.6964 - accuracy: 0.4969 - val_loss: 0.6972 - val_accuracy: 0.4750
# Epoch 3/100
# 40/40 [==============================] - 4s 102ms/step - loss: 0.6942 - accuracy: 0.4992 - val_loss: 0.6947 - val_accuracy: 0.4625
# Epoch 4/100
# 40/40 [==============================] - 4s 108ms/step - loss: 0.6937 - accuracy: 0.4906 - val_loss: 0.6933 - val_accuracy: 0.4938
# Epoch 5/100
# 40/40 [==============================] - 4s 103ms/step - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6950 - val_accuracy: 0.4531
# Epoch 6/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.6920 - accuracy: 0.5172 - val_loss: 0.6962 - val_accuracy: 0.4719
# Epoch 7/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6908 - accuracy: 0.5203 - val_loss: 0.7057 - val_accuracy: 0.4781
# Epoch 8/100
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6878 - accuracy: 0.5477 - val_loss: 0.6984 - val_accuracy: 0.4531
# Epoch 9/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0
100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.3299 - accuracy: 0.8547 - val_loss: 0.7079 - val_accuracy: 0.7250
# Epoch 88/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2829 - accuracy: 0.8789 - val_loss: 0.6891 - val_accuracy: 0.7406
# Epoch 89/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2838 - accuracy: 0.8734 - val_loss: 0.7119 - val_accuracy: 0.7437
# Epoch 90/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2629 - accuracy: 0.8844 - val_loss: 0.7580 - val_accuracy: 0.7312
# Epoch 91/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2682 - accuracy: 0.8797 - val_loss: 0.7796 - val_accuracy: 0.7437
# Epoch 92/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2915 - accuracy: 0.8727 - val_loss: 0.9342 - val_accuracy: 0.6844
# Epoch 93/100
# 40/40 [==============================] - 4s 87ms/step - loss: 0.3242 - accuracy: 0.8617 - val_loss: 0.7817 - val_accuracy: 0.7063
# Epoch 94/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2495 - accuracy: 0.8969 - val_loss: 0.7757 - val_accuracy: 0.7156
# Epoch 95/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2449 - accuracy: 0.8969 - val_loss: 0.8636 - val_accuracy: 0.7125
# Epoch 96/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.2649 - accuracy: 0.8906 - val_loss: 0.7622 - val_accuracy: 0.7437
# Epoch 97/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2294 - accuracy: 0.9047 - val_loss: 0.7295 - val_accuracy: 0.7469
# Epoch 98/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2219 - accuracy: 0.9031 - val_loss: 0.7050 - val_accuracy: 0.7563
# Epoch 99/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.2060 - accuracy: 0.9109 - val_loss: 0.8192 - val_accuracy: 0.7406
# Epoch 100/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.2758 - accuracy: 0.8891 - val_loss: 1.0663 - val_accuracy: 0.6656
# val_loss: 1.0663378238677979 val_accuracy: 0.6656249761581421
# 10/10 [==============================] - 2s 40ms/step
# El algoritmo acerto 213 veces sobre los 320 casos.

# %%
training_loss = results.history['loss']
test_loss = results.history['val_loss']
epochs_range = range(1, len(training_loss) + 1)

# %%
plt.plot(epochs_range, training_loss, 'r',marker="o",linestyle="--")
plt.plot(epochs_range, test_loss, 'b',marker="o",linestyle="-")
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.rcParams["figure.figsize"] = (20,8)
plt.grid()
plt.show()

# %%
k_fold = KFold(5)
fold = 0
y_tests = []
predictions = []
scores = []
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))
for train, test in k_fold.split(X):
    fold = fold + 1
    print(f"Fold #{fold}")
    X_train = X[train]
    X_test = X[test]
    y_train = y[train]
    y_test = y[test]
    print(f"Train - X:{X_train.shape} y:{y_train.shape}")
    print(f"Test - X:{X_test.shape} y:{y_test.shape}")
    
    num_labels = y.shape[1]
    dim_entrada = (X_train.shape[1],1)

    #model = new_RNN()
    model = new_RNN()
    callbacks = []
    '''
    callbacks = [
    EarlyStopping(
            monitor="val_loss",
            min_delta=1e-2,
            patience=20,
            verbose=1,
        )
    ]
    '''
    num_epochs = 60
    num_batch_size = 32
    start = datetime.datetime.now()
   
    results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test),callbacks=callbacks)

    pred = model.predict(X_test)
    y_tests.append(y_test)
    pred=[([1,0] if i[0]>i[1] else [0,1]) for i in pred]
    predictions.append(pred)
    score = metrics.accuracy_score(pred, y_test)
    math = confusion_matrix([(1 if x[0]==1 else 0) for x in pred],[(1 if x[0]==1 else 0) for x in y_test], labels=[1,0])
    scores.append([score])
    print(f"Fold score (Accuracy score): {score}")
    print("Matriz de confusion")
    print("-------------------")
    print("---------| Verdadero | Falso |")
    print(f"Verdadero|  {math[0][0]}        {math[0][1]}")
    print(f"Falso    |  {math[1][0]}        {math[1][1]}")

y_tests = np.concatenate(y_tests)
predictions = np.concatenate(predictions)
score = metrics.accuracy_score(predictions, y_tests)
print("-----------------------")
print(f"Cross-validated score (Accuracy score): {score}")
print("-----------------------")
print("Resumen")
for result in scores:
    print(f"Fold score (Accuracy score): {result[0]}")
    
#https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_05_2_kfold.ipynb
#https://www.youtube.com/watch?v=maiQf8ray_s
# Out:
# Fold #1
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 10s 128ms/step - loss: 0.6962 - accuracy: 0.4984 - val_loss: 0.7014 - val_accuracy: 0.4437
# Epoch 2/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6893 - accuracy: 0.5242 - val_loss: 0.7144 - val_accuracy: 0.4500
# Epoch 3/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6938 - accuracy: 0.5180 - val_loss: 0.6998 - val_accuracy: 0.4469
# Epoch 4/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6932 - accuracy: 0.5117 - val_loss: 0.7043 - val_accuracy: 0.4344
# Epoch 5/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6934 - accuracy: 0.5047 - val_loss: 0.6978 - val_accuracy: 0.4437
# Epoch 6/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.6916 - accuracy: 0.5188 - val_loss: 0.7007 - val_accuracy: 0.4500
# Epoch 7/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6917 - accuracy: 0.5180 - val_loss: 0.6939 - val_accuracy: 0.4719
# Epoch 8/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6914 - accuracy: 0.5289 - val_loss: 0.7029 - val_accuracy: 0.4344
# Epoch 9/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6938 - accuracy: 0.5117 - val_loss: 0.7003 - val_accuracy: 0.4375
# Epoch 10/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6920 - accuracy: 0.5203 - val_loss: 0.6952 - val_accuracy: 0.4437
# Epoch 11/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6898 - accuracy: 0.5188 - val_loss: 0.6985 - val_accuracy: 0.4437
# Epoch 12/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6914 - accuracy: 0.5312 - val_loss: 0.6946 - val_accuracy: 0.4719
# Epoch 13/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6914 - accuracy: 0.5141 - val_loss: 0.6993 - val_accuracy: 0.4437
# Epoch 14/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6868 - accuracy: 0.5148 - val_loss: 0.6909 - val_accuracy: 0.5250
# Epoch 15/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6934 - accuracy: 0.5250 - val_loss: 0.6898 - val_accuracy: 0.5625
# Epoch 16/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.6886 - accuracy: 0.5219 - val_loss: 0.6903 - val_accuracy: 0.5375
# Epoch 17/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.
60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5707 - accuracy: 0.7070 - val_loss: 0.6490 - val_accuracy: 0.6344
# Epoch 47/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5713 - accuracy: 0.7117 - val_loss: 0.7100 - val_accuracy: 0.6000
# Epoch 48/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5782 - accuracy: 0.7016 - val_loss: 0.7083 - val_accuracy: 0.6000
# Epoch 49/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5681 - accuracy: 0.7180 - val_loss: 0.6439 - val_accuracy: 0.6562
# Epoch 50/60
# 40/40 [==============================] - 4s 105ms/step - loss: 0.5442 - accuracy: 0.7195 - val_loss: 0.6975 - val_accuracy: 0.6000
# Epoch 51/60
# 40/40 [==============================] - 4s 98ms/step - loss: 0.5553 - accuracy: 0.7281 - val_loss: 0.6252 - val_accuracy: 0.6531
# Epoch 52/60
# 40/40 [==============================] - 4s 98ms/step - loss: 0.5231 - accuracy: 0.7461 - val_loss: 0.6432 - val_accuracy: 0.6719
# Epoch 53/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5191 - accuracy: 0.7484 - val_loss: 0.6524 - val_accuracy: 0.6438
# Epoch 54/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.4907 - accuracy: 0.7633 - val_loss: 0.6660 - val_accuracy: 0.6500
# Epoch 55/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5075 - accuracy: 0.7648 - val_loss: 0.6211 - val_accuracy: 0.6812
# Epoch 56/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5192 - accuracy: 0.7453 - val_loss: 0.6245 - val_accuracy: 0.6719
# Epoch 57/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.4811 - accuracy: 0.7797 - val_loss: 0.6787 - val_accuracy: 0.6562
# Epoch 58/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.4660 - accuracy: 0.7812 - val_loss: 0.6257 - val_accuracy: 0.6844
# Epoch 59/60
# 40/40 [==============================] - 4s 88ms/step - loss: 0.4622 - accuracy: 0.7867 - val_loss: 0.7138 - val_accuracy: 0.6406
# Epoch 60/60
# 40/40 [==============================] - 3s 87ms/step - loss: 0.4790 - accuracy: 0.7734 - val_loss: 0.6433 - val_accuracy: 0.6687
# 10/10 [==============================] - 2s 43ms/step
# Fold score (Accuracy score): 0.66875
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  128        60
# Falso    |  46        86
# Fold #2
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 10s 140ms/step - loss: 0.6970 - accuracy: 0.5031 - val_loss: 0.6933 - val_accuracy: 0.4844
# Epoch 2/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.6968 - accuracy: 0.5055 - val_loss: 0.6928 - val_accuracy: 0.4906
# Epoch 3/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6948 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5094
# Epoch 4/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6942 - accuracy: 0.5070 - val_loss: 0.6924 - val_accuracy: 0.5063
# Epoch 5/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.6928 - accuracy: 0.5008 - val_loss: 0.6934 - val_accuracy: 0.4844
# Epoch 6/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6940 - accuracy: 0.5188 - val_loss: 0.6926 - val_accuracy: 0.4906
# Epoch 7/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6922 - accuracy: 0.5172 - val_loss: 0.6917 - val_accuracy: 0.5000
# 40/40 [==============================] - 4s 95ms/step - loss: 0.5922 - accuracy: 0.6609 - val_loss: 0.6599 - val_accuracy: 0.5938
# Epoch 53/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5811 - accuracy: 0.6641 - val_loss: 0.6600 - val_accuracy: 0.6031
# Epoch 54/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5531 - accuracy: 0.6961 - val_loss: 0.7301 - val_accuracy: 0.6062
# Epoch 55/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.5558 - accuracy: 0.6742 - val_loss: 0.6894 - val_accuracy: 0.6156
# Epoch 56/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5597 - accuracy: 0.6938 - val_loss: 0.6408 - val_accuracy: 0.6344
# Epoch 57/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5434 - accuracy: 0.6977 - val_loss: 0.6670 - val_accuracy: 0.6094
# Epoch 58/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5300 - accuracy: 0.7250 - val_loss: 0.6264 - val_accuracy: 0.6281
# Epoch 59/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5182 - accuracy: 0.7266 - val_loss: 0.6976 - val_accuracy: 0.6250
# Epoch 60/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5194 - accuracy: 0.7109 - val_loss: 0.6908 - val_accuracy: 0.6344
# 10/10 [==============================] - 2s 40ms/step
# Fold score (Accuracy score): 0.634375
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  97        54
# Falso    |  63        106
# Fold #3
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 11s 134ms/step - loss: 0.6964 - accuracy: 0.4984 - val_loss: 0.6927 - val_accuracy: 0.5125
# Epoch 2/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6943 - accuracy: 0.5109 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 3/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6911 - accuracy: 0.5258 - val_loss: 0.6940 - val_accuracy: 0.4906
# Epoch 4/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6946 - accuracy: 0.5133 - val_loss: 0.6929 - val_accuracy: 0.5125
# Epoch 5/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6927 - accuracy: 0.5070 - val_loss: 0.6922 - val_accuracy: 0.5156
# Epoch 6/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6914 - accuracy: 0.5234 - val_loss: 0.6964 - val_accuracy: 0.5063
# Epoch 7/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6936 - accuracy: 0.5141 - val_loss: 0.6926 - val_accuracy: 0.5250
# Epoch 8/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6916 - accuracy: 0.5141 - val_loss: 0.6955 - val_accuracy: 0.4594
# Epoch 9/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6946 - accuracy: 0.4977 - val_loss: 0.6931 - val_accuracy: 0.5219
# Epoch 10/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6918 - accuracy: 0.5289 - val_loss: 0.6945 - val_accuracy: 0.5312
# Epoch 11/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6918 - accuracy: 0.5117 - val_loss: 0.6917 - val_accuracy: 0.4844
# Epoch 12/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6919 - accuracy: 0.5016 - val_loss: 0.6913 - val_accuracy: 0.5125
# Epoch 13/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6908 - accuracy: 0.5250 - val_loss: 0.6902 - val_accuracy: 0.5219
# Epoch 14/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6901 - accuracy: 0.5125 - val_loss: 0.6839 - val_accuracy: 0.5500
# Epoch 15/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.
60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6392 - accuracy: 0.6211 - val_loss: 0.6471 - val_accuracy: 0.5875
# Epoch 44/60
# 40/40 [==============================] - 4s 98ms/step - loss: 0.6413 - accuracy: 0.6297 - val_loss: 0.6484 - val_accuracy: 0.5875
# Epoch 45/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.6398 - accuracy: 0.6281 - val_loss: 0.6331 - val_accuracy: 0.6125
# Epoch 46/60
# 40/40 [==============================] - 4s 95ms/step - loss: 0.6278 - accuracy: 0.6344 - val_loss: 0.6358 - val_accuracy: 0.6094
# Epoch 47/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.6238 - accuracy: 0.6359 - val_loss: 0.6328 - val_accuracy: 0.6156
# Epoch 48/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6136 - accuracy: 0.6578 - val_loss: 0.6241 - val_accuracy: 0.6281
# Epoch 49/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6012 - accuracy: 0.6609 - val_loss: 0.6440 - val_accuracy: 0.6094
# Epoch 50/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6033 - accuracy: 0.6578 - val_loss: 0.6112 - val_accuracy: 0.6562
# Epoch 51/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5836 - accuracy: 0.6719 - val_loss: 0.6098 - val_accuracy: 0.6438
# Epoch 52/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5930 - accuracy: 0.6703 - val_loss: 0.6284 - val_accuracy: 0.6313
# Epoch 53/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5941 - accuracy: 0.6633 - val_loss: 0.6232 - val_accuracy: 0.6094
# Epoch 54/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5610 - accuracy: 0.6977 - val_loss: 0.6083 - val_accuracy: 0.6500
# Epoch 55/60
# 40/40 [==============================] - 4s 97ms/step - loss: 0.5475 - accuracy: 0.7109 - val_loss: 0.6378 - val_accuracy: 0.6125
# Epoch 56/60
# 40/40 [==============================] - 4s 96ms/step - loss: 0.5944 - accuracy: 0.6703 - val_loss: 0.6361 - val_accuracy: 0.6406
# Epoch 57/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5491 - accuracy: 0.7078 - val_loss: 0.6044 - val_accuracy: 0.6531
# Epoch 58/60
# 40/40 [==============================] - 4s 99ms/step - loss: 0.5377 - accuracy: 0.7242 - val_loss: 0.5633 - val_accuracy: 0.6844
# Epoch 59/60
# 40/40 [==============================] - 4s 102ms/step - loss: 0.5062 - accuracy: 0.7477 - val_loss: 0.5626 - val_accuracy: 0.6875
# Epoch 60/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5115 - accuracy: 0.7484 - val_loss: 0.5722 - val_accuracy: 0.6781
# 10/10 [==============================] - 2s 38ms/step
# Fold score (Accuracy score): 0.678125
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  105        49
# Falso    |  54        112
# Fold #4
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 1/60
# 40/40 [==============================] - 10s 129ms/step - loss: 0.6997 - accuracy: 0.4875 - val_loss: 0.6950 - val_accuracy: 0.4969
# Epoch 2/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6947 - accuracy: 0.4922 - val_loss: 0.6960 - val_accuracy: 0.4656
# Epoch 3/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6941 - accuracy: 0.4922 - val_loss: 0.6900 - val_accuracy: 0.5250
# Epoch 4/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.
60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6341 - accuracy: 0.6125 - val_loss: 0.6534 - val_accuracy: 0.5938
# Epoch 35/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6251 - accuracy: 0.6195 - val_loss: 0.6709 - val_accuracy: 0.5781
# Epoch 36/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6258 - accuracy: 0.6344 - val_loss: 0.6493 - val_accuracy: 0.6000
# Epoch 37/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6311 - accuracy: 0.6102 - val_loss: 0.6641 - val_accuracy: 0.5781
# Epoch 38/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6246 - accuracy: 0.6273 - val_loss: 0.6636 - val_accuracy: 0.5625
# Epoch 39/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6199 - accuracy: 0.6313 - val_loss: 0.6516 - val_accuracy: 0.5844
# Epoch 40/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6108 - accuracy: 0.6367 - val_loss: 0.6545 - val_accuracy: 0.5688
# Epoch 41/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.5961 - accuracy: 0.6469 - val_loss: 0.6749 - val_accuracy: 0.5844
# Epoch 42/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6094 - accuracy: 0.6445 - val_loss: 0.6383 - val_accuracy: 0.6000
# Epoch 43/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5947 - accuracy: 0.6469 - val_loss: 0.6550 - val_accuracy: 0.5875
# Epoch 44/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.6013 - accuracy: 0.6328 - val_loss: 0.6445 - val_accuracy: 0.6094
# Epoch 45/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6126 - accuracy: 0.6367 - val_loss: 0.6538 - val_accuracy: 0.5656
# Epoch 46/60
# 40/40 [==============================] - 4s 93ms/step - loss: 0.5903 - accuracy: 0.6633 - val_loss: 0.6687 - val_accuracy: 0.5781
# Epoch 47/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5736 - accuracy: 0.6687 - val_loss: 0.6548 - val_accuracy: 0.5813
# Epoch 48/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5885 - accuracy: 0.6523 - val_loss: 0.6687 - val_accuracy: 0.6062
# Epoch 49/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.6033 - accuracy: 0.6352 - val_loss: 0.6541 - val_accuracy: 0.5813
# Epoch 50/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5664 - accuracy: 0.6633 - val_loss: 0.6436 - val_accuracy: 0.6313
# Epoch 51/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.5710 - accuracy: 0.6586 - val_loss: 0.6279 - val_accuracy: 0.6219
# Epoch 52/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.5713 - accuracy: 0.6695 - val_loss: 0.6427 - val_accuracy: 0.5844
# Epoch 53/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5528 - accuracy: 0.6844 - val_loss: 0.6462 - val_accuracy: 0.6062
# Epoch 54/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5454 - accuracy: 0.6930 - val_loss: 0.6791 - val_accuracy: 0.5750
# Epoch 55/60
# 40/40 [==============================] - 4s 90ms/step - loss: 0.5599 - accuracy: 0.6648 - val_loss: 0.6844 - val_accuracy: 0.5969
# Epoch 56/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5357 - accuracy: 0.6758 - val_loss: 0.6298 - val_accuracy: 0.6406
# Epoch 57/60
# 40/40 [==============================] - 4s 94ms/step - loss: 0.5439 - accuracy: 0.6828 - val_loss: 0.6745 - val_accuracy: 0.5938
# Epoch 58/60
# 40/40 [==============================] - 4s 92ms/step - loss: 0.5316 - accuracy: 0.6984 - val_loss: 0.6111 - val_accuracy: 0.6625
# Epoch 59/60
# 40/40 [==============================] - 4s 91ms/step - loss: 0.5212 - accuracy: 0.6883 - val_loss: 0.6313 - val_accuracy: 0.6531
# Epoch 60/60
# 40/40 [==============================] - 4s 89ms/step - loss: 0.5173 - accuracy: 0.7055 - val_loss: 0.6945 - val_accuracy: 0.6094
# 10/10 [==============================] - 3s 64ms/step
# Fold score (Accuracy score): 0.609375
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  107        74
# Falso    |  51        88
# Fold #5
# Train - X:(1280, 40) y:(1280, 2)
# Test - X:(320, 40) y:(320, 2)
# Epoch 40/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6241 - accuracy: 0.6234 - val_loss: 0.7173 - val_accuracy: 0.5531
# Epoch 41/60
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6289 - accuracy: 0.6156 - val_loss: 0.7110 - val_accuracy: 0.5406
# Epoch 42/60
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6248 - accuracy: 0.6148 - val_loss: 0.6904 - val_accuracy: 0.5781
# Epoch 43/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6269 - accuracy: 0.6242 - val_loss: 0.6945 - val_accuracy: 0.5719
# Epoch 44/60
# 40/40 [==============================] - 7s 175ms/step - loss: 0.6329 - accuracy: 0.6109 - val_loss: 0.7113 - val_accuracy: 0.5562
# Epoch 45/60
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6209 - accuracy: 0.6258 - val_loss: 0.6979 - val_accuracy: 0.5281
# Epoch 46/60
# 40/40 [==============================] - 7s 172ms/step - loss: 0.6105 - accuracy: 0.6305 - val_loss: 0.7109 - val_accuracy: 0.5562
# Epoch 47/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6071 - accuracy: 0.6305 - val_loss: 0.6973 - val_accuracy: 0.5375
# Epoch 48/60
# 40/40 [==============================] - 7s 173ms/step - loss: 0.6098 - accuracy: 0.6266 - val_loss: 0.6916 - val_accuracy: 0.5844
# Epoch 49/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6071 - accuracy: 0.6492 - val_loss: 0.6885 - val_accuracy: 0.5750
# Epoch 50/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.6138 - accuracy: 0.6258 - val_loss: 0.6916 - val_accuracy: 0.5656
# Epoch 51/60
# 40/40 [==============================] - 7s 173ms/step - loss: 0.5974 - accuracy: 0.6336 - val_loss: 0.7107 - val_accuracy: 0.5906
# Epoch 52/60
# 40/40 [==============================] - 7s 175ms/step - loss: 0.5866 - accuracy: 0.6406 - val_loss: 0.7264 - val_accuracy: 0.5719
# Epoch 53/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.5878 - accuracy: 0.6445 - val_loss: 0.6908 - val_accuracy: 0.5781
# Epoch 54/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.5830 - accuracy: 0.6656 - val_loss: 0.6741 - val_accuracy: 0.5969
# Epoch 55/60
# 40/40 [==============================] - 7s 175ms/step - loss: 0.5596 - accuracy: 0.6719 - val_loss: 0.6758 - val_accuracy: 0.6187
# Epoch 56/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.5608 - accuracy: 0.6711 - val_loss: 0.6869 - val_accuracy: 0.5938
# Epoch 57/60
# 40/40 [==============================] - 7s 173ms/step - loss: 0.5511 - accuracy: 0.7008 - val_loss: 0.6923 - val_accuracy: 0.6031
# Epoch 58/60
# 40/40 [==============================] - 7s 174ms/step - loss: 0.5503 - accuracy: 0.6906 - val_loss: 0.7498 - val_accuracy: 0.6000
# Epoch 59/60
# 40/40 [==============================] - 7s 176ms/step - loss: 0.5612 - accuracy: 0.6664 - val_loss: 0.7077 - val_accuracy: 0.6125
# Epoch 60/60
# 40/40 [==============================] - 7s 173ms/step - loss: 0.5368 - accuracy: 0.7008 - val_loss: 0.7051 - val_accuracy: 0.5938
# 10/10 [==============================] - 2s 66ms/step
# Fold score (Accuracy score): 0.59375
# Matriz de confusion
# -------------------
# ---------| Verdadero | Falso |
# Verdadero|  93        74
# Falso    |  56        97
# -----------------------
# Cross-validated score (Accuracy score): 0.636875
# -----------------------
# Resumen
# Fold score (Accuracy score): 0.66875
# Fold score (Accuracy score): 0.634375
# Fold score (Accuracy score): 0.678125
# Fold score (Accuracy score): 0.609375
# Fold score (Accuracy score): 0.59375

# %%
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")

y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
    
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# val_loss: 0.7011466026306152 val_accuracy: 0.637499988079071
# El algoritmo acerto 240 veces sobre los 320 casos.

# %%
def new_RNN():
    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada, return_sequences=False))
#    model.add(LSTM(units=16,input_shape= dim_entrada, return_sequences=True))
#    model.add(LSTM(units=4,input_shape= dim_entrada, return_sequences=False))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    return model

'''
Cross-validated score (Accuracy score): 0.8200663349917081
-----------------------
Resumen
Fold score (Accuracy score): 0.8281573498964804
Fold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687
Fold score (Accuracy score): 0.8008298755186722
Fold score (Accuracy score): 0.8174273858921162
Fold score (Accuracy score): 0.8112033195020747
'''
# Out:
# '\nCross-validated score (Accuracy score): 0.8200663349917081\n-----------------------\nResumen\nFold score (Accuracy score): 0.8281573498964804\nFold score (Accuracy score): 0.8Detector de la mentira usando redes neuronales recurrentes426501035196687\nFold score (Accuracy score): 0.8008298755186722\nFold score (Accuracy score): 0.8174273858921162\nFold score (Accuracy score): 0.8112033195020747\n'

# %%
'''
val_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128
val_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128
val_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808
'''
# Out:
# '\nval_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128\nval_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128\nval_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808\n'

# %% [markdown]
# #### Crossvalidation

# %%
X = np.array(X)
y = np.array(y)
print(f"X:{X.shape} y:{y.shape}")
# Out:
# X:(2236, 40) y:(2236, 2)

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# El bloque realizara el k fold cross validation dividiendolo en 5 folds, se uso los MSE.

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_5.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
