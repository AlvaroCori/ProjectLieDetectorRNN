# %% [markdown]
# ## Antiguo proyecto de Redes Neuronales Recurrentes usando audios .wav, obteniendo su MFCC, aplicandolos a una RNN y validandolo con k fold cross validation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display
import os
import soundfile as sf
import json
import random
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
from keras import Sequential
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
import datetime
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
random.seed(0)

# %% [markdown]
# #### Conseguir los paths

# %% [markdown]
# La función consigue los caminos a los archivos de audio .wav pasándole una dirección del directorio y devolviendo el path de cada audio del dataset.

# %%
def get_files_from_path(directory):
    path_files = []
    dir_list = os.listdir(directory)
    for path in dir_list:
        path_files.append(directory+"\\"+path)
    return path_files

# %% [markdown]
# Con la lista de paths a los audios se va a recoger las emociones que necesitemos buscándolo por el código de emoción en el nombre del archivo para su distinción.
#
# (Es necesario conocer en qué posición está el código en el path, varía según el nivel que se encuentre en el path completo).

# %%
def extract_paths_for_emotions_keys(emotions_code, files_path, get_code):
    paths = []
    emotions_set = set(emotions_code)
    for code_file in files_path:
        if (get_code(code_file) in emotions_set):
            paths.append(code_file)
    return paths

def get_code_crema_d(path):
    return path[119:122]

def get_code_savee(path):
    return path[108]

# %% [markdown]
# Esta función abre el archivo .wav y obtiene el mfcc escalado en un vector de 40 elementos.

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    mfccs_features = librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
    return mfccs_scaled_features

# %% [markdown]
# Esta función permite guardar los MFCC en 'features', el código en 'code' y su dirección en 'path' en un archivo json.

# %%
def save_elements_in_json(examples_saved, name):
    json_files = []
    json_file = {}
    index = 0
    for file in examples_saved:
        json_file = {"id": index, "features":[str(elem) for elem in file[0]] ,"code":file[1], "path":file[2]}
        json_files.append(json_file)
        index += 1
    json_object = json.dumps(json_files)
    with open(f"{name}.json", "w") as outfile:
        outfile.write(json_object)

# %% [markdown]
# La función permite cargar datos del MFCC y código desde un archivo json.

# %%
def load_elements_from_json(name):
    f = open(f'{name}.json')
    data = json.load(f)
    examples = []
    for element in data:
        examples.append(([float(feature) for feature in (element["features"])], element["code"]))
    return examples

# %% [markdown]
# La función nos permite devolver una lista de MFCC obtenidos de una lista de paths.
#
#
# El MFCC tiene un límite que no le permite cargar archivos menor o igual a 44 kb.
#
# Con el diccionario obtenemos el total de audios recuperados por emoción.

# %%
def get_features(paths,get_code, files_filters = dict()):
    examples = []
    for path in paths:
        code = get_code(path)
        file_stats = os.stat(path)
        if (file_stats.st_size > 44):
            feature = features_extractor(path)
            files_filters[code]+= 1
            examples.append((feature,code))
    print(f"Se obtuvo el MFCC de unos {len(paths)} sobre {sum(files_filters[files] for files in files_filters)} audios.")
    return examples

# %% [markdown]
# Selecciona n ejemplos que necesitemos y los mezcla.

# %%
def select_elements(examples, code, quantity, new_code):
    random.shuffle(examples)
    elements = []
    counter = 1
    for example in examples:
        if (counter > quantity):
            break
        if code == example[1]:
            elements.append((example[0],new_code))
            counter = counter + 1
    return elements

# %% [markdown]
# Los siguientes bloques obtienen los paths y filtra las emociones que necesitemos en cada dataset (CREMA-D y SAVEE).

# %%
files_path = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\AudioWav")
emotions_code = ["NEU", "FEA","ANG"]
datas_files = extract_paths_for_emotions_keys(emotions_code, files_path, get_code_crema_d)

# %%
files_path_s = get_files_from_path(f"{os.getcwd()}\\..\\..\\Datasets\\ALL")
emotions_code_s = ["a", "f","n"]
datas_files_s = extract_paths_for_emotions_keys(emotions_code_s, files_path_s, get_code_savee)

# %%
examples = []
files_filters = dict()
files_filters["NEU"] = 0
files_filters["FEA"] = 0
files_filters["ANG"] = 0
files_filters["a"] = 0
files_filters["f"] = 0
files_filters["n"] = 0

# %% [markdown]
# Obtenemos los MFCC con su código de emoción para posteriormente unir los datos de ambos datasets.

# %%
examples = get_features(datas_files, get_code_crema_d, files_filters)
examples_s = get_features(datas_files_s, get_code_savee, files_filters)
es = examples + examples_s
entries = []
for example in es:
    entries.append((example[0], example[1]))
# Out:
# Se obtuvo el MFCC de unos 3629 sobre 7496 audios.
# Se obtuvo el MFCC de unos 240 sobre 7736 audios.

# %% [markdown]
# Obtendremos una cantidad de datos y cambiamos las claves a los labels {"without_stress" y "stress"} posteriormente se intercambia los datos, guardamos en X los MFCC e en y los labels, estos también se categorizan.

# %%
entries = []
for example in es:
    entries.append((example[0], example[1]))
datas = select_elements(entries, 'NEU', 896,"without_stress")
datas += select_elements(entries, 'ANG', 550, "stress")
datas += select_elements(entries, 'FEA', 550, "stress")
datas += select_elements(entries, 'a', 60, "stress")
datas += select_elements(entries, 'f', 60, "stress")
datas += select_elements(entries, 'n', 120, "without_stress")
random.shuffle(datas)

# %%
X = []
y = []
for data in datas:
    X.append(data[0])
    y.append(data[1])

# %%
labelencoder=preprocessing.LabelEncoder()
y = to_categorical(labelencoder.fit_transform(y))
y = np.array(y)

# %% [markdown]
# Se separa los datos en una parte para el entrenamiento y en otro para el testeo a partir de un porcentaje (0.8, 0.2).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2,random_state=0)

# %%
print(len(X_train),len(X_test),len(y_train),len(y_test))
# Out:
# 1788 448 1788 448

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# Esta es la implementación y arquitectura de la red neuronal.

# %%
#creacion del modelo
num_labels = y.shape[1]
dim_entrada = (X_train.shape[1],1)
    
#definiendo modelo
model = Sequential()
model.add(LSTM(units=50,input_shape= dim_entrada))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %% [markdown]
# Aqui se entrena el modelo y realizará varias iteraciones, posteriormente se puede conseguir el val_loss y el val_accuracy.

# %%
#numero de epocas
num_epochs = 50
num_batch_size = 32
start = datetime.datetime.now()
   
model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test))
duration = datetime.datetime.now() - start
# Out:
# Epoch 1/50
# 56/56 [==============================] - 6s 62ms/step - loss: 0.6743 - accuracy: 0.5699 - val_loss: 0.6491 - val_accuracy: 0.6138
# Epoch 2/50
# 56/56 [==============================] - 2s 39ms/step - loss: 0.6194 - accuracy: 0.6667 - val_loss: 0.6006 - val_accuracy: 0.6384
# Epoch 3/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.5822 - accuracy: 0.6918 - val_loss: 0.5923 - val_accuracy: 0.6406
# Epoch 4/50
# 56/56 [==============================] - 3s 53ms/step - loss: 0.5674 - accuracy: 0.7103 - val_loss: 0.5862 - val_accuracy: 0.6473
# Epoch 5/50
# 56/56 [==============================] - 3s 46ms/step - loss: 0.5633 - accuracy: 0.7125 - val_loss: 0.5838 - val_accuracy: 0.6518
# Epoch 6/50
# 56/56 [==============================] - 2s 43ms/step - loss: 0.5489 - accuracy: 0.7025 - val_loss: 0.5714 - val_accuracy: 0.6518
# Epoch 7/50
# 56/56 [==============================] - 3s 49ms/step - loss: 0.5504 - accuracy: 0.7081 - val_loss: 0.5817 - val_accuracy: 0.6629
# Epoch 8/50
# 56/56 [==============================] - 3s 47ms/step - loss: 0.5315 - accuracy: 0.7215 - val_loss: 0.5618 - val_accuracy: 0.6652
# Epoch 9/50
# 56/56 [==============================] - 3s 45ms/step - loss: 0.5323 - accuracy: 0.7304 - val_loss: 0.5508 - val_accuracy: 0.6674
# Epoch 10/50
# 56/56 [==============================] - 3s 49ms/step - loss: 0.5164 - accuracy: 0.7366 - val_loss: 0.5466 - val_accuracy: 0.6741
# Epoch 11/50
# 56/56 [==============================] - 3s 45ms/step - loss: 0.5143 - accuracy: 0.7416 - val_loss: 0.6056 - val_accuracy: 0.6585
# Epoch 12/50
# 56/56 [==============================] - 2s 41ms/step - loss: 0.5282 - accuracy: 0.7148 - val_loss: 0.5695 - val_accuracy: 0.6719
# Epoch 13/50
# 56/56 [==============================] - 2s 39ms/step - loss: 0.5197 - accuracy: 0.7232 - val_loss: 0.5613 - val_accuracy: 0.6786
# Epoch 14/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5146 - accuracy: 0.7349 - val_loss: 0.5457 - val_accuracy: 0.6674
# Epoch 15/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.5031 - accuracy: 0.7427 - val_loss: 0.5391 - val_accuracy: 0.6786
# Epoch 16/50
# 56/56 [==============================] - 2s 36ms/step - loss: 0.4931 - accuracy: 0.7411 - val_loss: 0.5451 - val_accuracy: 0.6741
# Epoch 17/50
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4886 - accuracy: 0.7366 - val_loss: 0.5483 - val_accuracy: 0.6853
# Epoch 18/50
# 56/56 [==============================] - 2s 44ms/step - loss: 0.4824 - accuracy: 0.7545 - val_loss: 0.5192 - val_accuracy: 0.7009
# Epoch 19/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4756 - accuracy: 0.7511 - val_loss: 0.5343 - val_accuracy: 0.7165
# Epoch 20/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4759 - accuracy: 0.7629 - val_loss: 0.5170 - val_accuracy: 0.7143
# Epoch 21/50
# 56/56 [==============================] - 2s 44ms/step - loss: 0.4798 - accuracy: 0.7427 - val_loss: 0.5121 - val_accuracy: 0.7098
# Epoch 22/50
# 56/56 [==============================] - 2s 41ms/step - loss: 0.4738 - accuracy: 0.7427 - val_loss: 0.5200 - val_accuracy: 0.7121
# Epoch 23/50
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4585 - accuracy: 0.7584 - val_loss: 0.5016 - val_accuracy: 0.7254
# Epoch 24/50
# 56/56 [==============================] - 2s 39ms/step - loss: 0.4520 - accuracy: 0.7668 - val_loss: 0.5199 - val_accuracy: 0.7188
# Epoch 25/50
# 56/56 [==============================] - 2s 41ms/step - loss: 0.4669 - accuracy: 0.7534 - val_loss: 0.5189 - val_accuracy: 0.7098
# Epoch 26/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.4441 - accuracy: 0.7645 - val_loss: 0.5287 - val_accuracy: 0.7143
# Epoch 27/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4576 - accuracy: 0.7573 - val_loss: 0.5431 - val_accuracy: 0.6741
# Epoch 28/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.4882 - accuracy: 0.7411 - val_loss: 0.5413 - val_accuracy: 0.7143
# Epoch 29/50
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4668 - accuracy: 0.7606 - val_loss: 0.5262 - val_accuracy: 0.7076
# Epoch 30/50
# 56/56 [==============================] - 2s 44ms/step - loss: 0.4542 - accuracy: 0.7489 - val_loss: 0.5233 - val_accuracy: 0.7098
# Epoch 31/50
# 56/56 [==============================] - 3s 44ms/step - loss: 0.4460 - accuracy: 0.7729 - val_loss: 0.5193 - val_accuracy: 0.7188
# Epoch 32/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.4609 - accuracy: 0.7645 - val_loss: 0.5374 - val_accuracy: 0.6942
# Epoch 33/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4352 - accuracy: 0.7752 - val_loss: 0.4932 - val_accuracy: 0.7366
# Epoch 34/50
# 56/56 [==============================] - 2s 36ms/step - loss: 0.4671 - accuracy: 0.7578 - val_loss: 0.5160 - val_accuracy: 0.7054
# Epoch 35/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4424 - accuracy: 0.7668 - val_loss: 0.5140 - val_accuracy: 0.7299
# Epoch 36/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4365 - accuracy: 0.7757 - val_loss: 0.5018 - val_accuracy: 0.7388
# Epoch 37/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.4192 - accuracy: 0.7757 - val_loss: 0.4964 - val_accuracy: 0.7478
# Epoch 38/50
# 56/56 [==============================] - 2s 36ms/step - loss: 0.4543 - accuracy: 0.7729 - val_loss: 0.5165 - val_accuracy: 0.7009
# Epoch 39/50
# 56/56 [==============================] - 2s 39ms/step - loss: 0.4480 - accuracy: 0.7673 - val_loss: 0.5134 - val_accuracy: 0.7321
# Epoch 40/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4365 - accuracy: 0.7685 - val_loss: 0.4976 - val_accuracy: 0.7433
# Epoch 41/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4394 - accuracy: 0.7729 - val_loss: 0.5114 - val_accuracy: 0.7277
# Epoch 42/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4324 - accuracy: 0.7746 - val_loss: 0.4914 - val_accuracy: 0.7344
# Epoch 43/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4329 - accuracy: 0.7808 - val_loss: 0.4917 - val_accuracy: 0.7232
# Epoch 44/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.4246 - accuracy: 0.7819 - val_loss: 0.4834 - val_accuracy: 0.7545
# Epoch 45/50
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4218 - accuracy: 0.7785 - val_loss: 0.5031 - val_accuracy: 0.7254
# Epoch 46/50
# 56/56 [==============================] - 2s 36ms/step - loss: 0.4173 - accuracy: 0.7841 - val_loss: 0.4965 - val_accuracy: 0.7344
# Epoch 47/50
# 56/56 [==============================] - 2s 40ms/step - loss: 0.4084 - accuracy: 0.7970 - val_loss: 0.4728 - val_accuracy: 0.7679
# Epoch 48/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4443 - accuracy: 0.7657 - val_loss: 0.5080 - val_accuracy: 0.7165
# Epoch 49/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4258 - accuracy: 0.7791 - val_loss: 0.4916 - val_accuracy: 0.7433
# Epoch 50/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4137 - accuracy: 0.7959 - val_loss: 0.4841 - val_accuracy: 0.7455

# %%
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
# Out:
# val_loss: 0.4840923845767975 val_accuracy: 0.7455357313156128

# %%
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
# Out:
# 14/14 [==============================] - 1s 14ms/step

# %%
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1

# %%
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# El algoritmo acerto 334 veces sobre los 448 casos.

# %% [markdown]
# El siguiente archivo guarda la configuración y los pesos.

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model_5.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_5.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# Esta línea guarda los datos obtenidos en cada corrida.

# %% [markdown]
# Este bloque ejecuta todo el código que vimos.

# %%
examples = []
files_filters = dict()
files_filters["NEU"] = 0
files_filters["FEA"] = 0
files_filters["ANG"] = 0
files_filters["a"] = 0
files_filters["f"] = 0
files_filters["n"] = 0
start = datetime.datetime.now()
examples = get_features(datas_files, get_code_crema_d, files_filters)
examples_s = get_features(datas_files_s, get_code_savee, files_filters)
end = datetime.datetime.now() - start
print(f"transcurrio {round((end.microseconds/1000000),2)} s")
es = examples + examples_s
entries = []
for example in es:
    entries.append((example[0], example[1]))
datas = select_elements(entries, 'NEU', 896,"without_stress")
datas += select_elements(entries, 'ANG', 550, "stress")
datas += select_elements(entries, 'FEA', 550, "stress")
datas += select_elements(entries, 'a', 60, "stress")
datas += select_elements(entries, 'f', 60, "stress")
datas += select_elements(entries, 'n', 120, "without_stress")
random.shuffle(datas)
X = []
y = []
for data in datas:
    X.append(data[0])
    y.append(data[1])
labelencoder=preprocessing.LabelEncoder()
y = to_categorical(labelencoder.fit_transform(y))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2,random_state=0)
print(len(X_train),len(X_test),len(y_train),len(y_test))
y = np.array(y)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
#creacion del modelo
num_labels = y.shape[1]
dim_entrada = (X_train.shape[1],1)
    
#definiendo modelo
model = Sequential()
model.add(LSTM(units=50,input_shape= dim_entrada))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
#numero de epocas
num_epochs = 50
num_batch_size = 32
start = datetime.datetime.now()
   
results = model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test))
duration = datetime.datetime.now() - start
test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"val_loss: {test_accuracy[0]}", f"val_accuracy: {test_accuracy[1]}")
y_values = model.predict(X_test)
y_prediction=[([1,0] if i[0]>i[1] else [0,1]) for i in y_values]
y_i = len(y_values)
i = 0
true_values = 0
while (i < y_i):
    true_values += (1 if (y_test[i][0] == y_prediction[i][0] or y_test[i][1] == y_prediction[i][1]) else 0)
    i = i + 1 
print(f"El algoritmo acerto {true_values} veces sobre los {y_i} casos.")
# Out:
# Se obtuvo el MFCC de unos 3629 sobre 3628 audios.
# Se obtuvo el MFCC de unos 240 sobre 3868 audios.
# transcurrio 0.3 s
# 1788 448 1788 448
# Epoch 1/50
# 56/56 [==============================] - 9s 60ms/step - loss: 0.6717 - accuracy: 0.5794 - val_loss: 0.6422 - val_accuracy: 0.6138
# Epoch 2/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.5998 - accuracy: 0.6644 - val_loss: 0.6129 - val_accuracy: 0.6362
# Epoch 3/50
# 56/56 [==============================] - 2s 36ms/step - loss: 0.5757 - accuracy: 0.6980 - val_loss: 0.6064 - val_accuracy: 0.6228
# Epoch 4/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.5674 - accuracy: 0.7002 - val_loss: 0.6027 - val_accuracy: 0.6451
# Epoch 5/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.5633 - accuracy: 0.7036 - val_loss: 0.5830 - val_accuracy: 0.6540
# Epoch 6/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5495 - accuracy: 0.7120 - val_loss: 0.5724 - val_accuracy: 0.6473
# Epoch 7/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.5442 - accuracy: 0.7148 - val_loss: 0.5728 - val_accuracy: 0.6629
# Epoch 8/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5353 - accuracy: 0.7159 - val_loss: 0.5840 - val_accuracy: 0.6696
# Epoch 9/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.5306 - accuracy: 0.7159 - val_loss: 0.5598 - val_accuracy: 0.6585
# Epoch 10/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.5195 - accuracy: 0.7254 - val_loss: 0.5579 - val_accuracy: 0.6786
# Epoch 11/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5177 - accuracy: 0.7371 - val_loss: 0.5536 - val_accuracy: 0.6853
# Epoch 12/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5184 - accuracy: 0.7276 - val_loss: 0.5489 - val_accuracy: 0.6830
# Epoch 13/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5184 - accuracy: 0.7315 - val_loss: 0.5408 - val_accuracy: 0.6830
# Epoch 14/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5087 - accuracy: 0.7338 - val_loss: 0.5402 - val_accuracy: 0.6875
# Epoch 15/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4885 - accuracy: 0.7489 - val_loss: 0.5394 - val_accuracy: 0.7098
# Epoch 16/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4872 - accuracy: 0.7567 - val_loss: 0.5498 - val_accuracy: 0.6786
# Epoch 17/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.4908 - accuracy: 0.7411 - val_loss: 0.6147 - val_accuracy: 0.6429
# Epoch 18/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.5083 - accuracy: 0.7243 - val_loss: 0.5281 - val_accuracy: 0.7031
# Epoch 19/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.4769 - accuracy: 0.7388 - val_loss: 0.5234 - val_accuracy: 0.7009
# Epoch 20/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4755 - accuracy: 0.7500 - val_loss: 0.5228 - val_accuracy: 0.6853
# Epoch 21/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.4736 - accuracy: 0.7578 - val_loss: 0.5514 - val_accuracy: 0.6674
# Epoch 22/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4652 - accuracy: 0.7673 - val_loss: 0.5769 - val_accuracy: 0.6875
# Epoch 23/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5001 - accuracy: 0.7299 - val_loss: 0.5442 - val_accuracy: 0.6808
# Epoch 24/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4778 - accuracy: 0.7494 - val_loss: 0.5211 - val_accuracy: 0.6875
# Epoch 25/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4749 - accuracy: 0.7506 - val_loss: 0.5555 - val_accuracy: 0.6853
# Epoch 26/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4660 - accuracy: 0.7657 - val_loss: 0.5149 - val_accuracy: 0.7143
# Epoch 27/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4518 - accuracy: 0.7668 - val_loss: 0.5108 - val_accuracy: 0.7188
# Epoch 28/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4507 - accuracy: 0.7696 - val_loss: 0.5227 - val_accuracy: 0.7121
# Epoch 29/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.4557 - accuracy: 0.7657 - val_loss: 0.5201 - val_accuracy: 0.7098
# Epoch 30/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4707 - accuracy: 0.7562 - val_loss: 0.5207 - val_accuracy: 0.7098
# Epoch 31/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4393 - accuracy: 0.7729 - val_loss: 0.5189 - val_accuracy: 0.7076
# Epoch 32/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4461 - accuracy: 0.7690 - val_loss: 0.5308 - val_accuracy: 0.7232
# Epoch 33/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4463 - accuracy: 0.7701 - val_loss: 0.5034 - val_accuracy: 0.7299
# Epoch 34/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4443 - accuracy: 0.7796 - val_loss: 0.4961 - val_accuracy: 0.7366
# Epoch 35/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.4290 - accuracy: 0.7864 - val_loss: 0.4940 - val_accuracy: 0.7411
# Epoch 36/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4301 - accuracy: 0.7757 - val_loss: 0.4858 - val_accuracy: 0.7567
# Epoch 37/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4216 - accuracy: 0.7869 - val_loss: 0.5145 - val_accuracy: 0.7210
# Epoch 38/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4316 - accuracy: 0.7768 - val_loss: 0.4716 - val_accuracy: 0.7589
# Epoch 39/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4548 - accuracy: 0.7578 - val_loss: 0.5085 - val_accuracy: 0.7188
# Epoch 40/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4367 - accuracy: 0.7713 - val_loss: 0.4882 - val_accuracy: 0.7567
# Epoch 41/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4352 - accuracy: 0.7796 - val_loss: 0.5049 - val_accuracy: 0.7344
# Epoch 42/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4174 - accuracy: 0.7891 - val_loss: 0.4936 - val_accuracy: 0.7433
# Epoch 43/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4202 - accuracy: 0.7813 - val_loss: 0.4691 - val_accuracy: 0.7500
# Epoch 44/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4135 - accuracy: 0.7931 - val_loss: 0.4751 - val_accuracy: 0.7433
# Epoch 45/50
# 56/56 [==============================] - 2s 38ms/step - loss: 0.4192 - accuracy: 0.7768 - val_loss: 0.5131 - val_accuracy: 0.7210
# Epoch 46/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4372 - accuracy: 0.7768 - val_loss: 0.5014 - val_accuracy: 0.7567
# Epoch 47/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.4587 - accuracy: 0.7729 - val_loss: 0.4942 - val_accuracy: 0.7232
# Epoch 48/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.4235 - accuracy: 0.7987 - val_loss: 0.4841 - val_accuracy: 0.7478
# Epoch 49/50
# 56/56 [==============================] - 2s 35ms/step - loss: 0.4246 - accuracy: 0.7836 - val_loss: 0.5084 - val_accuracy: 0.7299
# Epoch 50/50
# 56/56 [==============================] - 2s 37ms/step - loss: 0.4106 - accuracy: 0.7970 - val_loss: 0.4719 - val_accuracy: 0.7612
# val_loss: 0.4718780219554901 val_accuracy: 0.7611607313156128
# 14/14 [==============================] - 1s 12ms/step
# El algoritmo acerto 341 veces sobre los 448 casos.

# %%
training_loss = results.history['loss']
test_loss = results.history['val_loss']
epochs_range = range(1, len(training_loss) + 1)

# %%
plt.plot(epochs_range, training_loss, 'r',marker="o",linestyle="--")
plt.plot(epochs_range, test_loss, 'b',marker="o",linestyle="-")
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.rcParams["figure.figsize"] = (20,8)
plt.show()

# %%
'''
val_loss: 0.42675861716270447 val_accuracy: 0.7767857313156128
val_loss: 0.44326552748680115 val_accuracy: 0.7611607313156128
val_loss: 0.4475260078907013 val_accuracy: 0.7566964030265808
'''

# %% [markdown]
# #### Crossvalidation

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
X = np.array(X)
y = np.array(y)
print(f"X:{X.shape} y:{y.shape}")
# Out:
# X:(2236, 40) y:(2236, 2)

# %% [markdown]
# El bloque realizara el k fold cross validation dividiendolo en 5 folds, se uso los MSE.

# %%
k_fold = KFold(5)
fold = 0
y_tests = []
predictions = []
results = []
for train, test in k_fold.split(X):
    fold = fold + 1
    print(f"Fold #{fold}")
    
    X_train = X[train]
    X_test = X[test]
    y_train = y[train]
    y_test = y[test]
    print(f"Train - X:{X_train.shape} y:{y_train.shape}")
    print(f"Test - X:{X_test.shape} y:{y_test.shape}")
    
    num_labels = y.shape[1]
    dim_entrada = (X_train.shape[1],1)

    model = Sequential()
    model.add(LSTM(units=50,input_shape= dim_entrada))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(2,activation='softmax'))
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')
    
    num_epochs = 50
    num_batch_size = 32

    model.fit(X_train, y_train, batch_size=num_batch_size,epochs=num_epochs, validation_data=(X_test, y_test))
    
    pred = model.predict(X_test)
    y_tests.append(y_test)
    pred=[([1,0] if i[0]>i[1] else [0,1]) for i in pred]
    predictions.append(pred)
    score = metrics.accuracy_score(pred, y_test)
    results.append([score])
    print(f"Fold score (Accuracy score): {score}")

y_tests = np.concatenate(y_tests)
predictions = np.concatenate(predictions)
score = metrics.accuracy_score(pred, y_test)
print("-----------------------")
print(f"Cross-validated score (Accuracy score): {score}")
print("-----------------------")
print("Resumen")
for result in results:
    print(f"Fold score (MSE): {result[0]}")
    
#https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_05_2_kfold.ipynb
#https://www.youtube.com/watch?v=maiQf8ray_s
# Out:
# Fold #1
# Train - X:(1788, 40) y:(1788, 2)
# Test - X:(448, 40) y:(448, 2)
# Epoch 1/50
# 56/56 [==============================] - 5s 40ms/step - loss: 0.6792 - accuracy: 0.5515 - val_loss: 0.6663 - val_accuracy: 0.5558
# Epoch 2/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.6365 - accuracy: 0.6197 - val_loss: 0.5935 - val_accuracy: 0.6607
# Epoch 3/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.5995 - accuracy: 0.6706 - val_loss: 0.5604 - val_accuracy: 0.6964
# Epoch 4/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5738 - accuracy: 0.6913 - val_loss: 0.5471 - val_accuracy: 0.7165
# Epoch 5/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.5516 - accuracy: 0.7114 - val_loss: 0.5217 - val_accuracy: 0.7388
# Epoch 6/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5461 - accuracy: 0.7002 - val_loss: 0.5244 - val_accuracy: 0.7165
# Epoch 7/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.5274 - accuracy: 0.7148 - val_loss: 0.5058 - val_accuracy: 0.7388
# Epoch 8/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5382 - accuracy: 0.7097 - val_loss: 0.5499 - val_accuracy: 0.6897
# Epoch 9/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5373 - accuracy: 0.7092 - val_loss: 0.5127 - val_accuracy: 0.7299
# Epoch 10/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.5196 - accuracy: 0.7159 - val_loss: 0.5158 - val_accuracy: 0.7165
# Epoch 11/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5179 - accuracy: 0.7282 - val_loss: 0.5185 - val_accuracy: 0.7299
# Epoch 12/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5086 - accuracy: 0.7254 - val_loss: 0.4877 - val_accuracy: 0.7500
# Epoch 13/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4969 - accuracy: 0.7394 - val_loss: 0.4790 - val_accuracy: 0.7679
# Epoch 14/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.5055 - accuracy: 0.7254 - val_loss: 0.4658 - val_accuracy: 0.7634
# Epoch 15/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.5096 - accuracy: 0.7243 - val_loss: 0.4581 - val_accuracy: 0.7879
# Epoch 16/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4858 - accuracy: 0.7444 - val_loss: 0.4570 - val_accuracy: 0.7746
# Epoch 17/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4793 - accuracy: 0.7478 - val_loss: 0.4412 - val_accuracy: 0.7857
# Epoch 18/50
# 56/56 [==============================] - 1s 17ms/step - loss: 0.4832 - accuracy: 0.7539 - val_loss: 0.4690 - val_accuracy: 0.7478
# Epoch 19/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4796 - accuracy: 0.7494 - val_loss: 0.4638 - val_accuracy: 0.7835
# Epoch 20/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4910 - accuracy: 0.7399 - val_loss: 0.4895 - val_accuracy: 0.7545
# Epoch 21/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4996 - accuracy: 0.7209 - val_loss: 0.4853 - val_accuracy: 0.7545
# Epoch 22/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4891 - accuracy: 0.7394 - val_loss: 0.5164 - val_accuracy: 0.7165
# Epoch 23/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4832 - accuracy: 0.7450 - val_loss: 0.4679 - val_accuracy: 0.7567
# Epoch 24/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4783 - accuracy: 0.7494 - val_loss: 0.5136 - val_accuracy: 0.7210
# Epoch 25/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4625 - accuracy: 0.7528 - val_loss: 0.4655 - val_accuracy: 0.7902
# Epoch 26/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4653 - accuracy: 0.7623 - val_loss: 0.4260 - val_accuracy: 0.7991
# Epoch 27/50
# 56/56 [==============================] - 1s 27ms/step - loss: 0.4559 - accuracy: 0.7634 - val_loss: 0.4160 - val_accuracy: 0.7946
# Epoch 28/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4412 - accuracy: 0.7701 - val_loss: 0.4211 - val_accuracy: 0.8125
# Epoch 29/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4349 - accuracy: 0.7830 - val_loss: 0.4074 - val_accuracy: 0.8125
# Epoch 30/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4666 - accuracy: 0.7612 - val_loss: 0.4314 - val_accuracy: 0.8036
# Epoch 31/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4517 - accuracy: 0.7746 - val_loss: 0.4109 - val_accuracy: 0.8147
# Epoch 32/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4459 - accuracy: 0.7791 - val_loss: 0.4183 - val_accuracy: 0.7790
# Epoch 33/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4811 - accuracy: 0.7517 - val_loss: 0.4335 - val_accuracy: 0.7924
# Epoch 34/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4474 - accuracy: 0.7802 - val_loss: 0.4133 - val_accuracy: 0.7991
# Epoch 35/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4258 - accuracy: 0.7830 - val_loss: 0.4075 - val_accuracy: 0.8147
# Epoch 36/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4329 - accuracy: 0.7791 - val_loss: 0.4414 - val_accuracy: 0.7656
# Epoch 37/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4488 - accuracy: 0.7718 - val_loss: 0.4297 - val_accuracy: 0.7835
# Epoch 38/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4303 - accuracy: 0.7824 - val_loss: 0.3848 - val_accuracy: 0.8237
# Epoch 39/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4266 - accuracy: 0.7880 - val_loss: 0.4078 - val_accuracy: 0.8125
# Epoch 40/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4261 - accuracy: 0.7869 - val_loss: 0.3919 - val_accuracy: 0.8103
# Epoch 41/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4199 - accuracy: 0.7992 - val_loss: 0.3843 - val_accuracy: 0.8058
# Epoch 42/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4217 - accuracy: 0.7858 - val_loss: 0.3969 - val_accuracy: 0.8259
# Epoch 43/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4145 - accuracy: 0.7987 - val_loss: 0.3806 - val_accuracy: 0.8125
# Epoch 44/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4160 - accuracy: 0.7970 - val_loss: 0.4287 - val_accuracy: 0.7812
# Epoch 45/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4195 - accuracy: 0.7908 - val_loss: 0.3886 - val_accuracy: 0.8103
# Epoch 46/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4277 - accuracy: 0.7847 - val_loss: 0.4673 - val_accuracy: 0.7946
# Epoch 47/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4065 - accuracy: 0.8015 - val_loss: 0.4571 - val_accuracy: 0.7433
# Epoch 48/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4345 - accuracy: 0.7645 - val_loss: 0.4324 - val_accuracy: 0.7879
# Epoch 49/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4078 - accuracy: 0.7992 - val_loss: 0.3832 - val_accuracy: 0.8147
# Epoch 50/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4227 - accuracy: 0.7880 - val_loss: 0.4062 - val_accuracy: 0.8058
# 14/14 [==============================] - 1s 5ms/step
# Fold score (Accuracy score): 0.8058035714285714
# Fold #2
# Train - X:(1789, 40) y:(1789, 2)
# Test - X:(447, 40) y:(447, 2)
# Epoch 1/50
# 56/56 [==============================] - 4s 36ms/step - loss: 0.6799 - accuracy: 0.5511 - val_loss: 0.6541 - val_accuracy: 0.5548
# Epoch 2/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.6341 - accuracy: 0.6255 - val_loss: 0.5835 - val_accuracy: 0.6644
# Epoch 3/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5818 - accuracy: 0.6786 - val_loss: 0.5293 - val_accuracy: 0.7293
# Epoch 4/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5524 - accuracy: 0.6987 - val_loss: 0.5200 - val_accuracy: 0.7293
# Epoch 5/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5411 - accuracy: 0.7032 - val_loss: 0.5183 - val_accuracy: 0.7338
# Epoch 6/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5216 - accuracy: 0.7188 - val_loss: 0.4981 - val_accuracy: 0.7338
# Epoch 7/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5096 - accuracy: 0.7278 - val_loss: 0.4738 - val_accuracy: 0.7427
# Epoch 8/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5003 - accuracy: 0.7250 - val_loss: 0.4923 - val_accuracy: 0.7383
# Epoch 9/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5050 - accuracy: 0.7395 - val_loss: 0.4767 - val_accuracy: 0.7405
# Epoch 10/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5072 - accuracy: 0.7267 - val_loss: 0.5271 - val_accuracy: 0.7181
# Epoch 11/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4922 - accuracy: 0.7457 - val_loss: 0.4864 - val_accuracy: 0.7606
# Epoch 12/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4812 - accuracy: 0.7580 - val_loss: 0.4674 - val_accuracy: 0.7517
# Epoch 13/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4698 - accuracy: 0.7636 - val_loss: 0.4682 - val_accuracy: 0.7427
# Epoch 14/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4631 - accuracy: 0.7574 - val_loss: 0.4718 - val_accuracy: 0.7472
# Epoch 15/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4692 - accuracy: 0.7630 - val_loss: 0.4503 - val_accuracy: 0.7562
# Epoch 16/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4602 - accuracy: 0.7613 - val_loss: 0.4595 - val_accuracy: 0.7673
# Epoch 17/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4561 - accuracy: 0.7596 - val_loss: 0.4599 - val_accuracy: 0.7539
# Epoch 18/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4768 - accuracy: 0.7473 - val_loss: 0.5116 - val_accuracy: 0.7181
# Epoch 19/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4748 - accuracy: 0.7518 - val_loss: 0.4963 - val_accuracy: 0.7696
# Epoch 20/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4572 - accuracy: 0.7636 - val_loss: 0.5048 - val_accuracy: 0.7740
# Epoch 21/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4442 - accuracy: 0.7624 - val_loss: 0.4541 - val_accuracy: 0.7539
# Epoch 22/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4425 - accuracy: 0.7764 - val_loss: 0.4711 - val_accuracy: 0.7494
# Epoch 23/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4596 - accuracy: 0.7596 - val_loss: 0.4469 - val_accuracy: 0.7606
# Epoch 24/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4301 - accuracy: 0.7770 - val_loss: 0.4439 - val_accuracy: 0.7740
# Epoch 25/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4401 - accuracy: 0.7786 - val_loss: 0.4418 - val_accuracy: 0.7785
# Epoch 26/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4298 - accuracy: 0.7904 - val_loss: 0.4421 - val_accuracy: 0.7651
# Epoch 27/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4233 - accuracy: 0.7876 - val_loss: 0.4605 - val_accuracy: 0.7629
# Epoch 28/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4447 - accuracy: 0.7781 - val_loss: 0.5508 - val_accuracy: 0.6913
# Epoch 29/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5192 - accuracy: 0.7194 - val_loss: 0.4953 - val_accuracy: 0.7248
# Epoch 30/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4469 - accuracy: 0.7652 - val_loss: 0.4678 - val_accuracy: 0.7584
# Epoch 31/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4240 - accuracy: 0.7814 - val_loss: 0.4527 - val_accuracy: 0.7852
# Epoch 32/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4107 - accuracy: 0.7960 - val_loss: 0.4542 - val_accuracy: 0.7763
# Epoch 33/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4010 - accuracy: 0.7954 - val_loss: 0.4835 - val_accuracy: 0.7629
# Epoch 34/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4423 - accuracy: 0.7725 - val_loss: 0.5069 - val_accuracy: 0.7517
# Epoch 35/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4133 - accuracy: 0.7887 - val_loss: 0.4560 - val_accuracy: 0.7629
# Epoch 36/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4137 - accuracy: 0.7921 - val_loss: 0.4342 - val_accuracy: 0.7785
# Epoch 37/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4122 - accuracy: 0.7965 - val_loss: 0.4419 - val_accuracy: 0.7606
# Epoch 38/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4002 - accuracy: 0.7999 - val_loss: 0.4358 - val_accuracy: 0.7718
# Epoch 39/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.4098 - accuracy: 0.7842 - val_loss: 0.4478 - val_accuracy: 0.7651
# Epoch 40/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4105 - accuracy: 0.7898 - val_loss: 0.4707 - val_accuracy: 0.7562
# Epoch 41/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4210 - accuracy: 0.7831 - val_loss: 0.4617 - val_accuracy: 0.7651
# Epoch 42/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.3979 - accuracy: 0.8021 - val_loss: 0.4705 - val_accuracy: 0.7852
# Epoch 43/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.3882 - accuracy: 0.8172 - val_loss: 0.4966 - val_accuracy: 0.7651
# Epoch 44/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.3876 - accuracy: 0.8049 - val_loss: 0.4365 - val_accuracy: 0.7740
# Epoch 45/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4024 - accuracy: 0.8038 - val_loss: 0.4409 - val_accuracy: 0.7584
# Epoch 46/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.3886 - accuracy: 0.8099 - val_loss: 0.4639 - val_accuracy: 0.7785
# Epoch 47/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3847 - accuracy: 0.8195 - val_loss: 0.4848 - val_accuracy: 0.7651
# Epoch 48/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4013 - accuracy: 0.7909 - val_loss: 0.4274 - val_accuracy: 0.7852
# Epoch 49/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.3773 - accuracy: 0.8127 - val_loss: 0.4721 - val_accuracy: 0.7785
# Epoch 50/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.4300 - accuracy: 0.7781 - val_loss: 0.4843 - val_accuracy: 0.7383
# 14/14 [==============================] - 1s 7ms/step
# Fold score (Accuracy score): 0.738255033557047
# Fold #3
# Train - X:(1789, 40) y:(1789, 2)
# Test - X:(447, 40) y:(447, 2)
# Epoch 1/50
# 56/56 [==============================] - 4s 37ms/step - loss: 0.6864 - accuracy: 0.5299 - val_loss: 0.6543 - val_accuracy: 0.6085
# Epoch 2/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.6189 - accuracy: 0.6367 - val_loss: 0.5908 - val_accuracy: 0.6823
# Epoch 3/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.5865 - accuracy: 0.6708 - val_loss: 0.5827 - val_accuracy: 0.6801
# Epoch 4/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5591 - accuracy: 0.6998 - val_loss: 0.5663 - val_accuracy: 0.7047
# Epoch 5/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5488 - accuracy: 0.7065 - val_loss: 0.5648 - val_accuracy: 0.6980
# Epoch 6/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.5358 - accuracy: 0.7183 - val_loss: 0.5904 - val_accuracy: 0.6779
# Epoch 7/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5322 - accuracy: 0.7160 - val_loss: 0.5716 - val_accuracy: 0.7181
# Epoch 8/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5346 - accuracy: 0.7172 - val_loss: 0.5582 - val_accuracy: 0.7136
# Epoch 9/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5340 - accuracy: 0.7093 - val_loss: 0.6038 - val_accuracy: 0.6488
# Epoch 10/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.5341 - accuracy: 0.7160 - val_loss: 0.5305 - val_accuracy: 0.7248
# Epoch 11/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.5271 - accuracy: 0.7272 - val_loss: 0.5462 - val_accuracy: 0.7159
# Epoch 12/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5185 - accuracy: 0.7373 - val_loss: 0.5686 - val_accuracy: 0.7069
# Epoch 13/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4949 - accuracy: 0.7434 - val_loss: 0.5151 - val_accuracy: 0.7338
# Epoch 14/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5139 - accuracy: 0.7289 - val_loss: 0.5214 - val_accuracy: 0.7181
# Epoch 15/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.5059 - accuracy: 0.7295 - val_loss: 0.5012 - val_accuracy: 0.7405
# Epoch 16/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4746 - accuracy: 0.7608 - val_loss: 0.5075 - val_accuracy: 0.7204
# Epoch 17/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4901 - accuracy: 0.7401 - val_loss: 0.5404 - val_accuracy: 0.6868
# Epoch 18/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4798 - accuracy: 0.7451 - val_loss: 0.5024 - val_accuracy: 0.7338
# Epoch 19/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4755 - accuracy: 0.7563 - val_loss: 0.5139 - val_accuracy: 0.7360
# Epoch 20/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4830 - accuracy: 0.7462 - val_loss: 0.4936 - val_accuracy: 0.7606
# Epoch 21/50
# 56/56 [==============================] - 1s 27ms/step - loss: 0.4749 - accuracy: 0.7529 - val_loss: 0.4675 - val_accuracy: 0.7383
# Epoch 22/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4727 - accuracy: 0.7535 - val_loss: 0.5674 - val_accuracy: 0.7204
# Epoch 23/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4687 - accuracy: 0.7619 - val_loss: 0.5091 - val_accuracy: 0.7427
# Epoch 24/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4668 - accuracy: 0.7529 - val_loss: 0.4658 - val_accuracy: 0.7517
# Epoch 25/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4744 - accuracy: 0.7524 - val_loss: 0.4884 - val_accuracy: 0.7494
# Epoch 26/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4618 - accuracy: 0.7630 - val_loss: 0.4654 - val_accuracy: 0.7562
# Epoch 27/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4426 - accuracy: 0.7731 - val_loss: 0.7490 - val_accuracy: 0.6689
# Epoch 28/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4848 - accuracy: 0.7462 - val_loss: 0.4893 - val_accuracy: 0.7293
# Epoch 29/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4522 - accuracy: 0.7663 - val_loss: 0.4906 - val_accuracy: 0.7584
# Epoch 30/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4473 - accuracy: 0.7663 - val_loss: 0.5029 - val_accuracy: 0.7472
# Epoch 31/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4481 - accuracy: 0.7641 - val_loss: 0.4659 - val_accuracy: 0.7494
# Epoch 32/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4292 - accuracy: 0.7831 - val_loss: 0.4815 - val_accuracy: 0.7651
# Epoch 33/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4493 - accuracy: 0.7608 - val_loss: 0.4562 - val_accuracy: 0.7360
# Epoch 34/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4360 - accuracy: 0.7831 - val_loss: 0.4263 - val_accuracy: 0.7763
# Epoch 35/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4380 - accuracy: 0.7708 - val_loss: 0.4345 - val_accuracy: 0.7763
# Epoch 36/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4205 - accuracy: 0.7865 - val_loss: 0.4377 - val_accuracy: 0.7673
# Epoch 37/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4410 - accuracy: 0.7798 - val_loss: 0.4747 - val_accuracy: 0.7517
# Epoch 38/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4129 - accuracy: 0.7949 - val_loss: 0.4259 - val_accuracy: 0.7763
# Epoch 39/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4288 - accuracy: 0.7921 - val_loss: 0.4417 - val_accuracy: 0.7763
# Epoch 40/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.4251 - accuracy: 0.7826 - val_loss: 0.4278 - val_accuracy: 0.7718
# Epoch 41/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4026 - accuracy: 0.7937 - val_loss: 0.4271 - val_accuracy: 0.7808
# Epoch 42/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4207 - accuracy: 0.7915 - val_loss: 0.4481 - val_accuracy: 0.7450
# Epoch 43/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4034 - accuracy: 0.7909 - val_loss: 0.4416 - val_accuracy: 0.7584
# Epoch 44/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4195 - accuracy: 0.7842 - val_loss: 0.4451 - val_accuracy: 0.7763
# Epoch 45/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4114 - accuracy: 0.7842 - val_loss: 0.4809 - val_accuracy: 0.7405
# Epoch 46/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4369 - accuracy: 0.7691 - val_loss: 0.4182 - val_accuracy: 0.7673
# Epoch 47/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.3978 - accuracy: 0.8055 - val_loss: 0.4211 - val_accuracy: 0.7629
# Epoch 48/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4117 - accuracy: 0.7814 - val_loss: 0.4988 - val_accuracy: 0.7293
# Epoch 49/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4127 - accuracy: 0.8044 - val_loss: 0.4353 - val_accuracy: 0.7696
# Epoch 50/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4075 - accuracy: 0.7865 - val_loss: 0.4723 - val_accuracy: 0.7360
# 14/14 [==============================] - 1s 8ms/step
# Fold score (Accuracy score): 0.7360178970917226
# Fold #4
# Train - X:(1789, 40) y:(1789, 2)
# Test - X:(447, 40) y:(447, 2)
# Epoch 1/50
# 56/56 [==============================] - 6s 48ms/step - loss: 0.6843 - accuracy: 0.5388 - val_loss: 0.6735 - val_accuracy: 0.5727
# Epoch 2/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6327 - accuracy: 0.6350 - val_loss: 0.6130 - val_accuracy: 0.6622
# Epoch 3/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6006 - accuracy: 0.6685 - val_loss: 0.5871 - val_accuracy: 0.7002
# Epoch 4/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.5573 - accuracy: 0.7082 - val_loss: 0.6030 - val_accuracy: 0.6890
# Epoch 5/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5516 - accuracy: 0.7149 - val_loss: 0.5696 - val_accuracy: 0.6801
# Epoch 6/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.5315 - accuracy: 0.7272 - val_loss: 0.5702 - val_accuracy: 0.6935
# Epoch 7/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5263 - accuracy: 0.7239 - val_loss: 0.5482 - val_accuracy: 0.7181
# Epoch 8/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5164 - accuracy: 0.7323 - val_loss: 0.5240 - val_accuracy: 0.7271
# Epoch 9/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.5200 - accuracy: 0.7250 - val_loss: 0.5354 - val_accuracy: 0.7248
# Epoch 10/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.5126 - accuracy: 0.7317 - val_loss: 0.5210 - val_accuracy: 0.7517
# Epoch 11/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5082 - accuracy: 0.7367 - val_loss: 0.5416 - val_accuracy: 0.7069
# Epoch 12/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4960 - accuracy: 0.7423 - val_loss: 0.4990 - val_accuracy: 0.7427
# Epoch 13/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5195 - accuracy: 0.7401 - val_loss: 0.5135 - val_accuracy: 0.7315
# Epoch 14/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5096 - accuracy: 0.7317 - val_loss: 0.5522 - val_accuracy: 0.6913
# Epoch 15/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5015 - accuracy: 0.7328 - val_loss: 0.5181 - val_accuracy: 0.7338
# Epoch 16/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4830 - accuracy: 0.7479 - val_loss: 0.5023 - val_accuracy: 0.7360
# Epoch 17/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4816 - accuracy: 0.7580 - val_loss: 0.4972 - val_accuracy: 0.7360
# Epoch 18/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4734 - accuracy: 0.7663 - val_loss: 0.4970 - val_accuracy: 0.7450
# Epoch 19/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4819 - accuracy: 0.7541 - val_loss: 0.4736 - val_accuracy: 0.7517
# Epoch 20/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4855 - accuracy: 0.7501 - val_loss: 0.5058 - val_accuracy: 0.7315
# Epoch 21/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4618 - accuracy: 0.7619 - val_loss: 0.4655 - val_accuracy: 0.7651
# Epoch 22/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4445 - accuracy: 0.7854 - val_loss: 0.4923 - val_accuracy: 0.7360
# Epoch 23/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4724 - accuracy: 0.7529 - val_loss: 0.4819 - val_accuracy: 0.7494
# Epoch 24/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4631 - accuracy: 0.7680 - val_loss: 0.4657 - val_accuracy: 0.7494
# Epoch 25/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4617 - accuracy: 0.7680 - val_loss: 0.4819 - val_accuracy: 0.7472
# Epoch 26/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4491 - accuracy: 0.7770 - val_loss: 0.5062 - val_accuracy: 0.7562
# Epoch 27/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4633 - accuracy: 0.7630 - val_loss: 0.4948 - val_accuracy: 0.7383
# Epoch 28/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4476 - accuracy: 0.7703 - val_loss: 0.4554 - val_accuracy: 0.7651
# Epoch 29/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4584 - accuracy: 0.7658 - val_loss: 0.4967 - val_accuracy: 0.7651
# Epoch 30/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4313 - accuracy: 0.7826 - val_loss: 0.4823 - val_accuracy: 0.7383
# Epoch 31/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4479 - accuracy: 0.7658 - val_loss: 0.4659 - val_accuracy: 0.7494
# Epoch 32/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5249 - accuracy: 0.7267 - val_loss: 0.5281 - val_accuracy: 0.7069
# Epoch 33/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4909 - accuracy: 0.7423 - val_loss: 0.4952 - val_accuracy: 0.7494
# Epoch 34/50
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4682 - accuracy: 0.7479 - val_loss: 0.4626 - val_accuracy: 0.7606
# Epoch 35/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4529 - accuracy: 0.7708 - val_loss: 0.4535 - val_accuracy: 0.7606
# Epoch 36/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4312 - accuracy: 0.7792 - val_loss: 0.4414 - val_accuracy: 0.7606
# Epoch 37/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4289 - accuracy: 0.7837 - val_loss: 0.4447 - val_accuracy: 0.7651
# Epoch 38/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4161 - accuracy: 0.7893 - val_loss: 0.4282 - val_accuracy: 0.7785
# Epoch 39/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4321 - accuracy: 0.7814 - val_loss: 0.4374 - val_accuracy: 0.7651
# Epoch 40/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4115 - accuracy: 0.7971 - val_loss: 0.4318 - val_accuracy: 0.7696
# Epoch 41/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4047 - accuracy: 0.7954 - val_loss: 0.4312 - val_accuracy: 0.7808
# Epoch 42/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4341 - accuracy: 0.7725 - val_loss: 0.4503 - val_accuracy: 0.7606
# Epoch 43/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4137 - accuracy: 0.7954 - val_loss: 0.4342 - val_accuracy: 0.7651
# Epoch 44/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4195 - accuracy: 0.7909 - val_loss: 0.4454 - val_accuracy: 0.7629
# Epoch 45/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4106 - accuracy: 0.7971 - val_loss: 0.4417 - val_accuracy: 0.7718
# Epoch 46/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4089 - accuracy: 0.8021 - val_loss: 0.4488 - val_accuracy: 0.7696
# Epoch 47/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4120 - accuracy: 0.7887 - val_loss: 0.4387 - val_accuracy: 0.7718
# Epoch 48/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4045 - accuracy: 0.7926 - val_loss: 0.4508 - val_accuracy: 0.7629
# Epoch 49/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4080 - accuracy: 0.7932 - val_loss: 0.4408 - val_accuracy: 0.7673
# Epoch 50/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4033 - accuracy: 0.7954 - val_loss: 0.4410 - val_accuracy: 0.7673
# 14/14 [==============================] - 1s 8ms/step
# Fold score (Accuracy score): 0.767337807606264
# Fold #5
# Train - X:(1789, 40) y:(1789, 2)
# Test - X:(447, 40) y:(447, 2)
# Epoch 1/50
# 56/56 [==============================] - 4s 32ms/step - loss: 0.6867 - accuracy: 0.5338 - val_loss: 0.6660 - val_accuracy: 0.5817
# Epoch 2/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.6406 - accuracy: 0.6266 - val_loss: 0.6046 - val_accuracy: 0.6510
# Epoch 3/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5883 - accuracy: 0.6825 - val_loss: 0.5752 - val_accuracy: 0.6957
# Epoch 4/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5671 - accuracy: 0.7077 - val_loss: 0.5752 - val_accuracy: 0.6823
# Epoch 5/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.5670 - accuracy: 0.6942 - val_loss: 0.5830 - val_accuracy: 0.6711
# Epoch 6/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5580 - accuracy: 0.6982 - val_loss: 0.5535 - val_accuracy: 0.6980
# Epoch 7/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5349 - accuracy: 0.7065 - val_loss: 0.5317 - val_accuracy: 0.7047
# Epoch 8/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.5409 - accuracy: 0.7116 - val_loss: 0.5365 - val_accuracy: 0.6913
# Epoch 9/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5188 - accuracy: 0.7395 - val_loss: 0.5102 - val_accuracy: 0.7159
# Epoch 10/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5156 - accuracy: 0.7267 - val_loss: 0.5056 - val_accuracy: 0.7159
# Epoch 11/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5235 - accuracy: 0.7289 - val_loss: 0.4970 - val_accuracy: 0.7226
# Epoch 12/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.5226 - accuracy: 0.7300 - val_loss: 0.5196 - val_accuracy: 0.6868
# Epoch 13/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5132 - accuracy: 0.7244 - val_loss: 0.4956 - val_accuracy: 0.7159
# Epoch 14/50
# 56/56 [==============================] - 1s 19ms/step - loss: 0.4988 - accuracy: 0.7446 - val_loss: 0.5353 - val_accuracy: 0.7114
# Epoch 15/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5028 - accuracy: 0.7295 - val_loss: 0.5131 - val_accuracy: 0.7092
# Epoch 16/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4825 - accuracy: 0.7468 - val_loss: 0.5133 - val_accuracy: 0.7315
# Epoch 17/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4871 - accuracy: 0.7446 - val_loss: 0.4953 - val_accuracy: 0.7315
# Epoch 18/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4770 - accuracy: 0.7457 - val_loss: 0.4879 - val_accuracy: 0.7338
# Epoch 19/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4682 - accuracy: 0.7557 - val_loss: 0.5049 - val_accuracy: 0.7315
# Epoch 20/50
# 56/56 [==============================] - 1s 27ms/step - loss: 0.4768 - accuracy: 0.7518 - val_loss: 0.5068 - val_accuracy: 0.7248
# Epoch 21/50
# 56/56 [==============================] - 2s 34ms/step - loss: 0.4699 - accuracy: 0.7473 - val_loss: 0.5215 - val_accuracy: 0.7338
# Epoch 22/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4672 - accuracy: 0.7591 - val_loss: 0.5380 - val_accuracy: 0.6846
# Epoch 23/50
# 56/56 [==============================] - 1s 26ms/step - loss: 0.4682 - accuracy: 0.7423 - val_loss: 0.4815 - val_accuracy: 0.7494
# Epoch 24/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4731 - accuracy: 0.7580 - val_loss: 0.4951 - val_accuracy: 0.7360
# Epoch 25/50
# 56/56 [==============================] - 2s 27ms/step - loss: 0.4602 - accuracy: 0.7596 - val_loss: 0.4768 - val_accuracy: 0.7494
# Epoch 26/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4488 - accuracy: 0.7591 - val_loss: 0.4719 - val_accuracy: 0.7494
# Epoch 27/50
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4891 - accuracy: 0.7323 - val_loss: 0.5176 - val_accuracy: 0.7114
# Epoch 28/50
# 56/56 [==============================] - 2s 33ms/step - loss: 0.4696 - accuracy: 0.7557 - val_loss: 0.5005 - val_accuracy: 0.7159
# Epoch 29/50
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4734 - accuracy: 0.7462 - val_loss: 0.5053 - val_accuracy: 0.7181
# Epoch 30/50
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4570 - accuracy: 0.7552 - val_loss: 0.4921 - val_accuracy: 0.7204
# Epoch 31/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4509 - accuracy: 0.7585 - val_loss: 0.5001 - val_accuracy: 0.7338
# Epoch 32/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4428 - accuracy: 0.7675 - val_loss: 0.5126 - val_accuracy: 0.7092
# Epoch 33/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4436 - accuracy: 0.7652 - val_loss: 0.4917 - val_accuracy: 0.7539
# Epoch 34/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4530 - accuracy: 0.7513 - val_loss: 0.5617 - val_accuracy: 0.6823
# Epoch 35/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4613 - accuracy: 0.7479 - val_loss: 0.4915 - val_accuracy: 0.7405
# Epoch 36/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4374 - accuracy: 0.7708 - val_loss: 0.4827 - val_accuracy: 0.7606
# Epoch 37/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4365 - accuracy: 0.7669 - val_loss: 0.4767 - val_accuracy: 0.7405
# Epoch 38/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4379 - accuracy: 0.7619 - val_loss: 0.4943 - val_accuracy: 0.7472
# Epoch 39/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4398 - accuracy: 0.7647 - val_loss: 0.4685 - val_accuracy: 0.7472
# Epoch 40/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4267 - accuracy: 0.7742 - val_loss: 0.5904 - val_accuracy: 0.7204
# Epoch 41/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4300 - accuracy: 0.7814 - val_loss: 0.4994 - val_accuracy: 0.7606
# Epoch 42/50
# 56/56 [==============================] - 1s 25ms/step - loss: 0.4605 - accuracy: 0.7513 - val_loss: 0.5049 - val_accuracy: 0.7562
# Epoch 43/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4320 - accuracy: 0.7753 - val_loss: 0.4755 - val_accuracy: 0.7673
# Epoch 44/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4207 - accuracy: 0.7786 - val_loss: 0.4762 - val_accuracy: 0.7494
# Epoch 45/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4284 - accuracy: 0.7753 - val_loss: 0.4587 - val_accuracy: 0.7472
# Epoch 46/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.4242 - accuracy: 0.7831 - val_loss: 0.5306 - val_accuracy: 0.7562
# Epoch 47/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4174 - accuracy: 0.7775 - val_loss: 0.4712 - val_accuracy: 0.7315
# Epoch 48/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4203 - accuracy: 0.7814 - val_loss: 0.5033 - val_accuracy: 0.7517
# Epoch 49/50
# 56/56 [==============================] - 1s 24ms/step - loss: 0.4172 - accuracy: 0.7786 - val_loss: 0.4933 - val_accuracy: 0.7427
# Epoch 50/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4086 - accuracy: 0.7837 - val_loss: 0.4628 - val_accuracy: 0.7629
# 14/14 [==============================] - 1s 8ms/step
# Fold score (Accuracy score): 0.7628635346756152
# -----------------------
# Cross-validated score (Accuracy score): 0.7628635346756152
# -----------------------
# Resumen
# Fold score (MSE): 0.8058035714285714
# Fold score (MSE): 0.738255033557047
# Fold score (MSE): 0.7360178970917226
# Fold score (MSE): 0.767337807606264
# Fold score (MSE): 0.7628635346756152

# %%
'''
Cross-validated score (Accuracy score): 0.7874720357941835
-----------------------
Resumen
Fold score (MSE): 0.8169642857142857
Fold score (MSE): 0.7651006711409396
Fold score (MSE): 0.7695749440715883
Fold score (MSE): 0.7427293064876958
Fold score (MSE): 0.7874720357941835

Cross-validated score (Accuracy score): 0.7986577181208053
-----------------------
Resumen
Fold score (MSE): 0.8080357142857143
Fold score (MSE): 0.7718120805369127
Fold score (MSE): 0.7874720357941835
Fold score (MSE): 0.7762863534675615
Fold score (MSE): 0.7986577181208053


Cross-validated score (Accuracy score): 0.785234899328859
-----------------------
Resumen
Fold score (MSE): 0.7276785714285714
Fold score (MSE): 0.785234899328859
Fold score (MSE): 0.7516778523489933
Fold score (MSE): 0.8031319910514542
Fold score (MSE): 0.785234899328859
'''
